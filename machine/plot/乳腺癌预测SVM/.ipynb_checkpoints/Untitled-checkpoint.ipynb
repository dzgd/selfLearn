# %%
import pandas as pd
data = pd.read_excel(r"F:\11月30日各区县--居住地核查清单分析.xlsx" , sheet_name= "与户籍比对")
data.head()

# %%
data.head()
# Out:
#               公民身份证号码   姓名 性別  民族     出生年月      数据处理地        居住地详细地址  \
# 0  11010120131028102X  堵慧凝  女  汉族  2013-10  陕西省西安市雁塔区       详细地址无法联系
# 1  110102194404171140  王秀文  女  汉族   1944-4  陕西省西安市莲湖区      莲湖区宫园壹号1期
# 2  110102196601162234  李周利  男  汉族   1966-1  陕西省西安市雁塔区       212南区家属院
# 3  110102196702012374   杨军  男  汉族   1967-2  陕西省西安市莲湖区  陕西省西安市新城区尚荣小区
# 4  110102201603313116  龚孑修  男  汉族   2016-3  陕西省西安市雁塔区   陕煤小区2-4-1002
#
#           联系方式 复查状态 复查情况      区县              派出所名称    统计机构代码
# 0  13572769098  未复查  NaN  610113   西安市公安局高新分局鱼斗路派出所  610161.0
# 1  13325484546  未复查  NaN  610104    西安市公安局莲湖分局北关派出所  610104.0
# 2  13709267733  未复查  NaN  610113   西安市公安局高新分局高新路派出所  610161.0
# 3  17719549770  未复查  NaN  610104  西安市公安局莲湖分局劳动南路派出所  610104.0
# 4  18291107787  未复查  NaN  610113   西安市公安局高新分局高新路派出所  610161.0

# %%
data.shape
# Out:
# (338880, 13)

# %%
# Out:
#               公民身份证号码   姓名 性別  民族     出生年月      数据处理地        居住地详细地址  \
# 0  11010120131028102X  堵慧凝  女  汉族  2013-10  陕西省西安市雁塔区       详细地址无法联系
# 1  110102194404171140  王秀文  女  汉族   1944-4  陕西省西安市莲湖区      莲湖区宫园壹号1期
# 2  110102196601162234  李周利  男  汉族   1966-1  陕西省西安市雁塔区       212南区家属院
# 3  110102196702012374   杨军  男  汉族   1967-2  陕西省西安市莲湖区  陕西省西安市新城区尚荣小区
# 4  110102201603313116  龚孑修  男  汉族   2016-3  陕西省西安市雁塔区   陕煤小区2-4-1002
#
#           联系方式 复查状态 复查情况      区县              派出所名称    统计机构代码
# 0  13572769098  未复查  NaN  610113   西安市公安局高新分局鱼斗路派出所  610161.0
# 1  13325484546  未复查  NaN  610104    西安市公安局莲湖分局北关派出所  610104.0
# 2  13709267733  未复查  NaN  610113   西安市公安局高新分局高新路派出所  610161.0
# 3  17719549770  未复查  NaN  610104  西安市公安局莲湖分局劳动南路派出所  610104.0
# 4  18291107787  未复查  NaN  610113   西安市公安局高新分局高新路派出所  610161.0

# %%
import os
import pandas as pd
import time
start =time.time()
result = pd.DataFrame()


df = df.loc[df["居住地详细地址"].str.contains("新城区" | "韩森寨" | "长乐中"|),:]
#df1 = df.groupby("品牌")["销售额"].sum().reset_index()
result = pd.concat(df)
    
end = time.time()
print("所花费时间：%.2f"%(end-start))
reg = result.iloc[:,[0,2,3,4,8,9,10,11,12,13,14]]
reg
reg.to_csv(r'D:\统计局\your.csv', index=False,encoding="GBK")
