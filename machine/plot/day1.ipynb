# %%
pip install pyecharts
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
tips = pd.read_csv(r"D:\面板数据文件\seaborn\seaborn-data-master\seaborn-data-master\tips.csv")
print(tips.head())
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.scatterplot(x = "total_bill",y="tip",hue="time",style="time",size="time",data=tips)
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
plt.scatter(tips["total_bill"],tips["tip"],c = "red",marker ="x")

# %%
from pyecharts.charts import Scatter
from pyecharts import options as opts
scatter = Scatter()
scatter.add_xaxis(tips["total_bill"])
scatter.add_yaxis("小费金额",tips["tip"])
scatter.set_global_opts(xaxis_opts=opts.AxisOpts(splitline_opts=opts.SplitLineOpts(is_show=True)),
                        yaxis_opts=opts.AxisOpts(splitline_opts=opts.SplitLineOpts(is_show=True)),
                        toolbox_opts=opts.ToolboxOpts(is_show=True))
scatter.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="9da2ebb138ea45739ba01f53e9ee23eb" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_9da2ebb138ea45739ba01f53e9ee23eb = echarts.init(
#                     document.getElementById('9da2ebb138ea45739ba01f53e9ee23eb'), 'white', {renderer: 'canvas'});
#                 var option_9da2ebb138ea45739ba01f53e9ee23eb = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
# ...

# %%
t1 = tips.copy()
t1.sort_values(by = "total_bill",inplace = True)
plt.plot(t1["total_bill"],t1["tip"])
plt.show()

# %%
sns.lineplot(x = "total_bill",y = "tip" , data = tips)

# %%
# %matplotlib inline
from pyecharts.charts import Line
line = Line()
line.add_xaxis(t1["total_bill"])
line.add_yaxis("标题",t1["tip"])
line.render_notebook()
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts':'https://assets.pyecharts.org/assets/echarts.min'
#         }
#     });
# </script>
#
#         <div id="f21c1eceaa5e401094de1e65ba1f851f" style="width:900px; height:500px;"></div>
#
# <script>
#         require(['echarts'], function(echarts) {
#                 var chart_f21c1eceaa5e401094de1e65ba1f851f = echarts.init(
#                     document.getElementById('f21c1eceaa5e401094de1e65ba1f851f'), 'white', {renderer: 'canvas'});
#                 var option_f21c1eceaa5e401094de1e65ba1f851f = {
#     "animation": true,
#     "animationThreshold": 2000,
#     "animationDuration": 1000,
#     "animationEasing": "cubicOut",
#     "animationDelay": 0,
#     "animationDurationUpdate": 300,
#     "animationEasingUpdate": "cubicOut",
#     "animationDelayUpdate": 0,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
# ...

# %%
line.render("line.html")
# Out:
# 'E:\\environment\\machine\\plot\\line.html'

# %%
from pyecharts import options as opts
from pyecharts.charts import Line
from pyecharts.faker import Faker

line = Line()
line.add_xaxis(Faker.choose())
line.add_yaxis("商家A",Faker.values(),stack="0")
line.add_yaxis("商家B",Faker.values(),stack="0")
line.add_yaxis("商家C",Faker.values(),stack="0")
line.set_global_opts(title_opts=opts.TitleOpts(title="堆叠折线图"),
                     tooltip_opts=opts.TooltipOpts(trigger="axis"),  # 坐标轴触发
                     xaxis_opts=opts.AxisOpts(boundary_gap=False),   # 默认True类目轴中刻度作为分隔
                     yaxis_opts=opts.AxisOpts(splitline_opts=opts.SplitLineOpts(is_show=True)))   # 显示分割线
line.set_series_opts(label_opts=opts.LabelOpts(is_show=False))
line.render("line_stack.html")
# Out:
# 'E:\\environment\\machine\\plot\\line_stack.html'

# %%
from pyecharts.charts import Bar
 
bar = Bar("我的第一个图表", "这里是副标题")
bar.add("服装", ["衬衫", "羊毛衫", "雪纺衫", "裤子", "高跟鞋", "袜子"], [5, 20, 36, 10, 75, 90])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-35-13c32f20530d> in <module>
#       1 from pyecharts.charts import Bar
#       2
# ----> 3 bar = Bar("我的第一个图表", "这里是副标题")
#       4 bar.add("服装", ["衬衫", "羊毛衫", "雪纺衫", "裤子", "高跟鞋", "袜子"], [5, 20, 36, 10, 75, 90])
#
# TypeError: __init__() takes from 1 to 2 positional arguments but 3 were given

# %%
import pandas as pd
df = pd.DataFrame({"a":[1,3,5],"b":[2,4,6]})
df
# Out:
#    a  b
# 0  1  2
# 1  3  4
# 2  5  6

# %%
df.iloc[0]   #series
# Out:
# a    1
# b    2
# Name: 0, dtype: int64

# %%
df.iloc[[0]]   #dataframe
# Out:
#    a  b
# 0  1  2

# %%
df.iloc[[0,2]]
# Out:
#    a  b
# 0  1  2
# 2  5  6

# %%
df.iloc[1:3]
# Out:
#    a  b
# 1  3  4
# 2  5  6

# %%
df.iloc[:,[False,True]]
# Out:
#    b
# 0  2
# 1  4
# 2  6

# %%
df.iloc[[False,True,True],:]
# Out:
#    a  b
# 1  3  4
# 2  5  6

# %%
df.iloc[(df["a"]>4).to_list(),:]
# Out:
#    a  b
# 2  5  6

# %%
df.loc[df["a"]>4,:]
# Out:
#    a  b
# 2  5  6

# %%
df["a"]>4
# Out:
# 0    False
# 1    False
# 2     True
# Name: a, dtype: bool

# %%
df["a"].to_list()
# Out:
# [1, 3, 5]

# %%
(df["a"]>4).to_list()
# Out:
# [False, False, True]
