# %%
import gopup as gp
df = gp.weibo_index(word="疫情", time_type="1hour")
print(df)
# Out:
#                         疫情
# index
# 2021-01-05 22:20:00  60550
# 2021-01-05 22:25:00  22503
# 2021-01-05 22:30:00  41604
# 2021-01-05 22:35:00  26106
# 2021-01-05 22:40:00  26279
# 2021-01-05 22:45:00  27681
# 2021-01-05 22:50:00  25929
# 2021-01-05 22:55:00  23807
# 2021-01-05 23:00:00  11897
# 2021-01-05 23:05:00  10244
# 2021-01-05 23:10:00  16566
# 2021-01-05 23:15:00  59098
# 2021-01-05 23:20:00  27119

# %%
import gopup as gp
df_index = gp.nicorn_company()
print(df_index)
# Out:
#        com_id                                   com_logo_archive com_name  \
# 0       18092  https://cdn.itjuzi.com/images/900637e42dec75cc...     蚂蚁金服
# 1    34048160  https://cdn.itjuzi.com/images/c36e423fd300b774...     字节跳动
# 2       24348  https://cdn.itjuzi.com/images/116bef02d9859fbf...      阿里云
# 3         157  https://cdn.itjuzi.com/images/8badb6e5188dbfb3...       滴滴
# 4       16470  https://cdn.itjuzi.com/images/2b4263b060d94abd...      陆金所
# ..        ...                                                ...      ...
# 235     33165  https://cdn.itjuzi.com/images/a2cf983fdaf9f738...     菜鸟网络
# 236       519  https://cdn.itjuzi.com/images/e23167abf44a656e...       快手
# 237     10886  https://cdn.itjuzi.com/images/71aed313c7ab511f...       大疆
# 238     16575  https://cdn.itjuzi.com/images/530422542495801a...     微众银行
# 239      1491  https://cdn.itjuzi.com/images/ee732b6094be97d3...      猿辅导
#
#     com_prov com_city  invse_year  invse_month  invse_day  \
# ...

# %%
import pandas as pd
df = pd.DataFrame(df_index)
df
# Out:
#        com_id                                   com_logo_archive com_name  \
# 0       18092  https://cdn.itjuzi.com/images/900637e42dec75cc...     蚂蚁金服
# 1    34048160  https://cdn.itjuzi.com/images/c36e423fd300b774...     字节跳动
# 2       24348  https://cdn.itjuzi.com/images/116bef02d9859fbf...      阿里云
# 3         157  https://cdn.itjuzi.com/images/8badb6e5188dbfb3...       滴滴
# 4       16470  https://cdn.itjuzi.com/images/2b4263b060d94abd...      陆金所
# ..        ...                                                ...      ...
# 235     33165  https://cdn.itjuzi.com/images/a2cf983fdaf9f738...     菜鸟网络
# 236       519  https://cdn.itjuzi.com/images/e23167abf44a656e...       快手
# 237     10886  https://cdn.itjuzi.com/images/71aed313c7ab511f...       大疆
# 238     16575  https://cdn.itjuzi.com/images/530422542495801a...     微众银行
# 239      1491  https://cdn.itjuzi.com/images/ee732b6094be97d3...      猿辅导
#
#     com_prov com_city  invse_year  invse_month  invse_day  \
# ...

# %%
import gopup as gp
g = gp.pro_api(token = "……")
df_index = pd.DataFrame(g.weibo_user(keyword="雷军"))
df_index
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-4-25cf4a635cbe> in <module>
#       1 import gopup as gp
#       2 g = gp.pro_api(token = "……")
# ----> 3 df_index = pd.DataFrame(g.weibo_user(keyword="雷军"))
#       4 df_index
#
# E:\environment\lib\site-packages\gopup\pro\client.py in query(self, api_name, fields, **kwargs)
#      46             result = json.loads(res.text)
#      47             if result['error_code'] != 200:
# ---> 48                 raise Exception(result['msg'])
#      49             data = result['data']
#      50             columns = data['fields']
#
# Exception: {'token': ['Token不正确,请到http://www.gopup.cn注册获取Token']}

# %%
import gopup as gp
df_index = gp.realtime_boxoffice()
print(df_index)
# Out:
# [Errno 2] No such file or directory: 'E:\\environment\\lib\\site-packages\\gopup\\movie\\webDES.js'

# %%
import gopup as gp
df_index = gp.day_boxoffice(date="2020-10-10")
print(df_index)
# Out:
# [Errno 2] No such file or directory: 'E:\\environment\\lib\\site-packages\\gopup\\movie\\webDES.js'

# %%
import gopup as gp
df_index = gp.university()
print(df_index)
# Out:
#         序号        学校名称       学校标识码      主管部门      所在省市        所在地 办学层次  备注
# 0        1        北京大学  4111010001       教育部       北京市        北京市   本科
# 1        2      中国人民大学  4111010002       教育部       北京市        北京市   本科
# 2        3        清华大学  4111010003       教育部       北京市        北京市   本科
# 3        4      北京交通大学  4111010004       教育部       北京市        北京市   本科
# 4        5      北京工业大学  4111010005       北京市       北京市        北京市   本科
# ...    ...         ...         ...       ...       ...        ...  ...  ..
# 2626  2627    哈密职业技术学院  4165014524  新疆维吾尔自治区  新疆维吾尔自治区        哈密市   专科
# 2627  2628  新疆科技职业技术学院  4165014525  新疆自治区教育厅  新疆维吾尔自治区      乌鲁木齐市   专科  民办
# 2628  2629   吐鲁番职业技术学院  4165014585  新疆维吾尔自治区  新疆维吾尔自治区       吐鲁番市   专科
# 2629  2630  博尔塔拉职业技术学院  4165014622  新疆维吾尔自治区  新疆维吾尔自治区  博尔塔拉蒙古自治州   专科
# 2630  2631  新疆工业职业技术学院  4265051060  新疆维吾尔自治区  新疆维吾尔自治区      乌鲁木齐市   专科
#
# [2631 rows x 8 columns]

# %%
df_index
# Out:
#         序号        学校名称       学校标识码      主管部门      所在省市        所在地 办学层次  备注
# 0        1        北京大学  4111010001       教育部       北京市        北京市   本科
# 1        2      中国人民大学  4111010002       教育部       北京市        北京市   本科
# 2        3        清华大学  4111010003       教育部       北京市        北京市   本科
# 3        4      北京交通大学  4111010004       教育部       北京市        北京市   本科
# 4        5      北京工业大学  4111010005       北京市       北京市        北京市   本科
# ...    ...         ...         ...       ...       ...        ...  ...  ..
# 2626  2627    哈密职业技术学院  4165014524  新疆维吾尔自治区  新疆维吾尔自治区        哈密市   专科
# 2627  2628  新疆科技职业技术学院  4165014525  新疆自治区教育厅  新疆维吾尔自治区      乌鲁木齐市   专科  民办
# 2628  2629   吐鲁番职业技术学院  4165014585  新疆维吾尔自治区  新疆维吾尔自治区       吐鲁番市   专科
# 2629  2630  博尔塔拉职业技术学院  4165014622  新疆维吾尔自治区  新疆维吾尔自治区  博尔塔拉蒙古自治州   专科
# 2630  2631  新疆工业职业技术学院  4265051060  新疆维吾尔自治区  新疆维吾尔自治区      乌鲁木齐市   专科
#
# [2631 rows x 8 columns]

# %%
df_index.head(20)
# Out:
#     序号      学校名称       学校标识码     主管部门 所在省市  所在地 办学层次 备注
# 0    1      北京大学  4111010001      教育部  北京市  北京市   本科
# 1    2    中国人民大学  4111010002      教育部  北京市  北京市   本科
# 2    3      清华大学  4111010003      教育部  北京市  北京市   本科
# 3    4    北京交通大学  4111010004      教育部  北京市  北京市   本科
# 4    5    北京工业大学  4111010005      北京市  北京市  北京市   本科
# 5    6  北京航空航天大学  4111010006  工业和信息化部  北京市  北京市   本科
# 6    7    北京理工大学  4111010007  工业和信息化部  北京市  北京市   本科
# 7    8    北京科技大学  4111010008      教育部  北京市  北京市   本科
# 8    9    北方工业大学  4111010009      北京市  北京市  北京市   本科
# 9   10    北京化工大学  4111010010      教育部  北京市  北京市   本科
# 10  11    北京工商大学  4111010011      北京市  北京市  北京市   本科
# 11  12    北京服装学院  4111010012      北京市  北京市  北京市   本科
# 12  13    北京邮电大学  4111010013      教育部  北京市  北京市   本科
# 13  14    北京印刷学院  4111010015      北京市  北京市  北京市   本科
# 14  15    北京建筑大学  4111010016      北京市  北京市  北京市   本科
# 15  16  北京石油化工学院  4111010017      北京市  北京市  北京市   本科
# 16  17  北京电子科技学院  4111010018    中央办公厅  北京市  北京市   本科
# ...

# %%
import gopup as gp
covid_163_df = gp.covid_163(indicator="疫情学术进展")
covid_163_df
# Out:
#                                                 url3g             docid  \
# 0   https://3g.163.com/news/20/0720/19/FI0KVTS9000...  FI0KVTS900019NGP
# 1   https://3g.163.com/news/20/0720/19/FI0LNTF5000...  FI0LNTF500019NGP
# 2   https://3g.163.com/news/20/0320/22/F86RA0JH000...  F86RA0JH00019NGP
# 3   http://3g.163.com/news/20/0313/01/F7IG6B4I0001...  F7IG6B4I00019NGP
# 4   http://3g.163.com/news/20/0306/11/F71IP6280001...  F71IP62800019NGP
# 5   http://3g.163.com/news/20/0303/11/F6PQGDCD0001...  F6PQGDCD00019NGP
# 6   http://3g.163.com/news/20/0210/14/F51HPI890001...  F51HPI8900019NGP
# 7   http://3g.163.com/news/20/0228/23/F6GRTAMN0001...  F6GRTAMN00019NGP
# 8   http://3g.163.com/news/20/0226/23/F6BMVT3J0001...  F6BMVT3J00019NGP
# 9   http://3g.163.com/news/20/0218/12/F5LUK0DH0001...  F5LUK0DH00019NGP
# 10  http://3g.163.com/news/20/0224/20/F666OE460001...  F666OE4600019NGP
# 11  http://3g.163.com/news/20/0222/01/F5V0QV880001...  F5V0QV8800019NGP
# ...

# %%
covid_163_df.loc[5]
# Out:
# url3g           http://3g.163.com/news/20/0303/11/F6PQGDCD0001...
# docid                                            F6PQGDCD00019NGP
# lspri                                                          60
# finearticle                                                     1
# source                                                  胸部疾病杂志JTD
# dkeys                                         钟南山,流行病,sars,感染,病例数
# title                                  钟南山:国内新冠疫情4月见顶，总感染规模约为9.5万
# userid                                                       zxli
# url             https://news.163.com/20/0303/11/F6PQGDCD00019N...
# quality                                                        80
# imgsrc3gtype                                                    1
# topicid                                                  00019NGQ
# nickname                                                      小肥猪
# digest          钟南山团队用SEIR和LSTM两种模型对疫情进行评估，推算如果封城等管控延迟5天，疫情规模将...
# ...

# %%
import gopup as gp
covid_163_df = gp.covid_163(indicator="前沿知识")
covid_163_df
# Out:
#                           title                source  \
# 0      Nature：新冠病毒自然进化 不可能是人为制造       2020.03.18 自然杂志
# 1     钟南山:国内新冠疫情4月见顶，总感染规模约9.5万  2020.03.02 胸部疾病杂志JTD
# 2  张文宏:上海已止住病例的指数增长，传播力比预期降低99%    2020.02.24 medRvix
# 3        管轶:检测表明穿山甲可能是新冠病毒的中间宿主    2020.02.18 bioRvix
#
#                                               detail  \
# 0  通过比较已知冠状病毒株的基因组序列数据，可以确定新冠病毒起源于自然过程，并非人为制造；起源方...
# 1  钟南山团队用SEIR和LSTM两种模型对疫情进行评估，推算如果封城等管控延迟5天，疫情规模将...
# 2
# 3
#
#                                                 link
# 0  https://vip.open.163.com/mobile/activity/ncov/...
# 1  https://vip.open.163.com/mobile/activity/ncov/...
# 2  https://vip.open.163.com/mobile/activity/ncov/...
# 3  https://vip.open.163.com/mobile/activity/ncov/...

# %%
covid_163_df.iloc[0,2]
# Out:
# '通过比较已知冠状病毒株的基因组序列数据，可以确定新冠病毒起源于自然过程，并非人为制造；起源方式有两种，一是病毒通过自然选择在非人类宿主中进化到目前的致病状态，然后跳到人类身上；在另一种设想中，病毒的非致病性版本从动物宿主跳到人类，然后在人类中进化到目前的致病性状态'
