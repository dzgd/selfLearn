# %%
from sklearn.ensemble import RandomForestRegressor as RFR
from sklearn.model_selection import cross_val_score
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from sklearn import decomposition
data = pd.read_csv(r"C:\Users\Administrator\Desktop\table1_end_data.csv")
data = data.drop(columns = "id")
x = data.iloc[:,1:]
y = data.iloc[:,0]
kernels=['linear','poly']
mse_linear = []
mse_poly = []
for i in kernels:
    for j in range(2,30):
        kpca=decomposition.KernelPCA(n_components=j,kernel=i)
        kpca = kpca.fit_transform(x)
        once = cross_val_score(RFR(n_estimators=20,random_state= 0 ),kpca,y,scoring = "neg_mean_squared_error",cv=10).mean()
        if i == "linear" :
            mse_linear.append(once * -1)
        if i == "poly" :
            mse_poly.append(once * -1)
      

color = ["red" , "blue"]       
fig = plt.figure(figsize=[20,5])
mse = [mse_linear , mse_poly ]
mse_char = ["mse_linear" , "mse_poly" ]
for i ,col in enumerate(mse) :
    ax = fig.add_subplot(1,2,i+1)## 两行两列，每个单元显示核函数为 rbf 的 KernelPCA 一组参数的效果图
    ax.plot(range(2,30), col ,color = color[i] ,label = mse_char[i])
    ax.set_xlabel("number of components after dimension reduction")
    ax.set_ylabel(mse_char[i])
    ax.legend(loc="best")
    n = np.argmin(col)+2
    print("{}的mse最小时所需要的降维为{},均方误差最小为{}".format(mse_char[i],n,col[n-2]))
plt.suptitle("KPCA")
#plt.show()
plt.savefig(r"C:\Users\Administrator\Desktop\linear_or_poly.jpg")
  

    
fig = plt.figure(figsize=[20,5])
colors = ["red" ,"yellow" ,"green" , "blue"]
Gammas=[0.1,0.5,1,4]
Gammas_char=["gamma = 0.1","gamma = 0.5","gamma = 1","gamma = 4"]# rbf 核的参数组成的列表。每个参数就是 gamma值
for i,gamma in enumerate(Gammas):
    mse_rbf = []
    for j in range(1,10):
        kpca=decomposition.KernelPCA(n_components=j,kernel='rbf',gamma=gamma)
        kpca = kpca.fit_transform(x)
        once = cross_val_score(RFR(n_estimators=20,random_state= 0 ),kpca,y,scoring = "neg_mean_squared_error",cv=10).mean()
        mse_rbf.append(once * -1)
    ax = fig.add_subplot(2,2,i+1)## 两行两列，每个单元显示核函数为 rbf 的 KernelPCA 一组参数的效果图
    ax.plot(range(1,10), mse_rbf ,color = colors[i] ,label = Gammas_char[i])
    ax.set_xlabel("number of components after dimension reduction ")
    ax.set_ylabel("mse_rbf")
    ax.legend(loc="best")
    n = np.argmin(mse_rbf)+1
    print("{}的mse最小时所需要的降维为{},均方误差最小为{}".format(Gammas_char[i],n,mse_rbf[n-1]))
plt.suptitle("KPCA-rbf")
#plt.show()
plt.savefig(r"C:\Users\Administrator\Desktop\KPCA_rbf.jpg")
    

    
    
#####已经确定选用核函数为poly时用26个变量进行降维处理并导出#############    
    
kpca=decomposition.KernelPCA(n_components=26,kernel="poly")
kpca = kpca.fit_transform(x)
var_poly = ["var1","var2","var3","var4","var5","var6","var7","var8","var9"
       ,"var10","var11","var12","var13","var14","var15","var16","var7"
       ,"var18","var19","var20","var21","var22","var23","var24","var25"
       ,"var26"]
x_fe_poly = pd.DataFrame(kpca,columns = var_poly )
xx = pd.read_csv(r"C:\Users\Administrator\Desktop\table1_end_data.csv").iloc[:,0:2]
x_fe_poly_concat = pd.concat([xx , x_fe_poly] , axis = 1)
x_fe_poly_concat.to_csv(r"C:\Users\Administrator\Desktop\x_fe_poly.csv" , index = None)
fit_26 = RFR(n_estimators=20,random_state= 0).fit(x_fe_poly,y)
features = x_fe_poly.columns
importances = fit_26.feature_importances_
indices = np.argsort(importances[0:10])  # top 10 features
plt.title('Feature Importances')
plt.barh(range(len(indices)), importances[indices], color='g', align='center')
plt.yticks(range(len(indices)), [features[i] for i in indices])
plt.xlabel('Relative Importance')
#plt.show()
plt.savefig(r"C:\Users\Administrator\Desktop\Relative_Tmportance.jpg")
# Out:
# mse_linear的mse最小时所需要的降维为6,均方误差最小为0.05721385179924242
# mse_poly的mse最小时所需要的降维为26,均方误差最小为0.05356035511363637
# gamma = 0.1的mse最小时所需要的降维为8,均方误差最小为0.05665390388257576
# gamma = 0.5的mse最小时所需要的降维为6,均方误差最小为0.05591588304924243
# gamma = 1的mse最小时所需要的降维为9,均方误差最小为0.05569495738636363
# gamma = 4的mse最小时所需要的降维为3,均方误差最小为0.06144072679924243

# %%
enumerate

# %%
from sklearn.ensemble import RandomForestRegressor as RFR
from sklearn.model_selection import cross_val_score
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from sklearn import decomposition
data = pd.read_csv(r"C:\Users\Administrator\Desktop\table1_end_data.csv")
data = data.drop(columns = "id")
x = data.iloc[:,1:]
y = data.iloc[:,0]
kernels=['linear','poly']
mse_linear = []
mse_poly = []
for i in kernels:
    for j in range(2,30):
        kpca=decomposition.KernelPCA(n_components=j,kernel=i)
        kpca = kpca.fit_transform(x)
        once = cross_val_score(RFR(n_estimators=20,random_state= 0 ),kpca,y,scoring = "neg_mean_squared_error",cv=10).mean()
        if i == "linear" :
            mse_linear.append(once * -1)
        if i == "poly" :
            mse_poly.append(once * -1)
      

color = ["red" , "blue"]       
fig = plt.figure(figsize=[20,5] ,dpi = 250)
mse = [mse_linear , mse_poly ]
mse_char = ["mse_linear" , "mse_poly" ]
for i ,col in enumerate(mse) :
    ax = fig.add_subplot(1,2,i+1)## 两行两列，每个单元显示核函数为 rbf 的 KernelPCA 一组参数的效果图
    ax.plot(range(2,30), col ,color = color[i] ,label = mse_char[i])
    ax.set_xlabel("number of components after dimension reduction")
    ax.set_ylabel(mse_char[i])
    ax.legend(loc="best")
    n = np.argmin(col)+2
    print("{}的mse最小时所需要的降维为{},均方误差最小为{}".format(mse_char[i],n,col[n-2]))
plt.suptitle("KPCA")
#plt.show()
fig.tight_layout()
plt.savefig(r"C:\Users\Administrator\Desktop\linear_or_poly.jpg")
# Out:
# mse_linear的mse最小时所需要的降维为6,均方误差最小为0.05721385179924242
# mse_poly的mse最小时所需要的降维为26,均方误差最小为0.05356035511363637

# %%
   
fig = plt.figure(figsize=[20,5] ,dpi = 250)
colors = ["red" ,"yellow" ,"green" , "blue"]
Gammas=[0.1,0.5,1,4]
Gammas_char=["gamma = 0.1","gamma = 0.5","gamma = 1","gamma = 4"]# rbf 核的参数组成的列表。每个参数就是 gamma值
for i,gamma in enumerate(Gammas):
    mse_rbf = []
    for j in range(1,10):
        kpca=decomposition.KernelPCA(n_components=j,kernel='rbf',gamma=gamma)
        kpca = kpca.fit_transform(x)
        once = cross_val_score(RFR(n_estimators=20,random_state= 0 ),kpca,y,scoring = "neg_mean_squared_error",cv=10).mean()
        mse_rbf.append(once * -1)
    ax = fig.add_subplot(2,2,i+1)## 两行两列，每个单元显示核函数为 rbf 的 KernelPCA 一组参数的效果图
    ax.plot(range(1,10), mse_rbf ,color = colors[i] ,label = Gammas_char[i])
    ax.set_xlabel("number of components after dimension reduction ")
    ax.set_ylabel("mse_rbf")
    ax.legend(loc="best")
    n = np.argmin(mse_rbf)+1
    print("{}的mse最小时所需要的降维为{},均方误差最小为{}".format(Gammas_char[i],n,mse_rbf[n-1]))
plt.suptitle("KPCA-rbf")
fig.tight_layout()
#plt.show()
plt.savefig(r"C:\Users\Administrator\Desktop\KPCA_rbf.jpg")
# Out:
# gamma = 0.1的mse最小时所需要的降维为4,均方误差最小为0.055388115530303025
# gamma = 0.5的mse最小时所需要的降维为7,均方误差最小为0.05768482007575758
# gamma = 1的mse最小时所需要的降维为3,均方误差最小为0.05562563446969697
# gamma = 4的mse最小时所需要的降维为6,均方误差最小为0.05882460464015151

# %%
    
#####已经确定选用核函数为poly时用26个变量进行降维处理并导出#############    
fig = plt.figure(figsize=[8,5] ,dpi = 250)   
kpca=decomposition.KernelPCA(n_components=26,kernel="poly")
kpca = kpca.fit_transform(x)
var_poly = ["var1","var2","var3","var4","var5","var6","var7","var8","var9"
       ,"var10","var11","var12","var13","var14","var15","var16","var7"
       ,"var18","var19","var20","var21","var22","var23","var24","var25"
       ,"var26"]
x_fe_poly = pd.DataFrame(kpca,columns = var_poly )
xx = pd.read_csv(r"C:\Users\Administrator\Desktop\table1_end_data.csv").iloc[:,0:2]
x_fe_poly_concat = pd.concat([xx , x_fe_poly] , axis = 1)
x_fe_poly_concat.to_csv(r"C:\Users\Administrator\Desktop\x_fe_poly.csv" , index = None)
fit_26 = RFR(n_estimators=20,random_state= 0).fit(x_fe_poly,y)
features = x_fe_poly.columns
importances =fit_26.feature_importances_ 

e = [0 , 13]
for k , i in enumerate(e):
    indices = np.argsort(importances )# features
    indices = indices[i:i+13]
    plt.subplot(2,1,k+1)
    plt.title(' %d and %d Feature Importances' % (i+1 , i+13))
    plt.barh(range(len(indices)), importances[indices], color='g', align='center')
    plt.yticks(range(len(indices)), [features[i] for i in indices])
    plt.xlabel('Relative Importance')
fig.tight_layout()
#plt.show()
plt.savefig(r"C:\Users\Administrator\Desktop\Relative_Tmportance.jpg")

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.layers import Dropout, Dense, SimpleRNN
import matplotlib.pyplot as plt
import os
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error
import math
data = pd.read_csv(r"C:\Users\Administrator\Desktop\x_fe_poly.csv")
data = data.sort_values('id', ascending = False)


training_set = data.iloc[0:325 - 50, : ].values  # 前(325-50=275)天的数据作为训练集,表格从0开始计数
test_set = data.iloc[325 - 50: , : ].values  # 后50天的数据作为测试集

# 归一化
sc_x = MinMaxScaler(feature_range=(0, 1))  # 定义归一化：归一化到(0，1)之间
sc_y = MinMaxScaler(feature_range=(0, 1))  # 定义归一化：归一化到(0，1)之间
training_set_scaled_x = sc_x.fit_transform(training_set[:,2:])  # 求得训练集的最大值，最小值这些训练集固有的属性，并在训练集上进行归一化
training_set_scaled_y = sc_y.fit_transform(training_set[:,1:2])  # 求得训练集的最大值，最小值这些训练集固有的属性，并在训练集上进行归一化
test_set_x = sc_x.transform(test_set[:,2:])  # 利用训练集的属性对测试集进行归一化
test_set_y = sc_y.transform(test_set[:,1:2])  # 利用训练集的属性对测试集进行归一化

x_train = []
y_train = []

x_test = []
y_test = []

# 测试集：csv表格中前325-50=275个数据
# 利用for循环，遍历整个训练集，提取训练集中连续5天的26个降维新变量作为输入特征x_train，第6天的RON_LOSS作为标签，for循环共构建325-50-5=270组数据。

for i in range(5, len(training_set_scaled_x)):
    x_train.append(training_set_scaled_x[i - 5:i, :])
    y_train.append(training_set_scaled_y[i, :])
# 对训练集进行打乱
np.random.seed(7)
np.random.shuffle(x_train)
np.random.seed(7)
np.random.shuffle(y_train)
tf.random.set_seed(7)
# 将训练集由list格式变为array格式
x_train, y_train = np.array(x_train), np.array(y_train)

# 使x_train符合RNN输入要求：[送入样本数， 循环核时间展开步数， 每个时间步输入特征个数]。
# 此处整个数据集送入，送入样本数为x_train.shape[0]即270组数据；输入连续5个的26个降维新变量，预测出第6天的RON_LOSS，循环核时间展开步数为5; 每个时间步送入的特征是连续5天的26个降维新变量，有26个数据，故每个时间步输入特征个数为26
x_train = np.reshape(x_train, (x_train.shape[0], 5, 26))
# 测试集：csv表格中后50天数据
# 利用for循环，遍历整个测试集，提取测试集中连续5天的26个降维新变量作为输入特征x_train，第6天的数据作为RON_LOSS，for循环共构建50-5=45组数据。
for i in range(5, len(test_set_x)):
    x_test.append(test_set_x[i - 5 : i, :])
    y_test.append(test_set_y[i, :])
# 测试集变array并reshape为符合RNN输入要求：[送入样本数， 循环核时间展开步数， 每个时间步输入特征个数]
x_test, y_test = np.array(x_test), np.array(y_test)
x_test = np.reshape(x_test, (x_test.shape[0], 5, 26))

model_RNN = tf.keras.Sequential([
    SimpleRNN(80, return_sequences=True),
    Dropout(0.2),
    SimpleRNN(100),
    Dropout(0.2),
    Dense(1)
])

model_RNN.compile(optimizer=tf.keras.optimizers.Adam(0.001),
              loss='mean_squared_error')  # 损失函数用均方误差
# 该应用只观测loss数值，不观测准确率，所以删去metrics选项，一会在每个epoch迭代显示时只显示loss值
#C:\Users\Administrator\Desktop\
checkpoint_save_path = r"C:\Users\Administrator\Desktop\RNNcheckpoint\RNN_RON_LOSS.ckpt"

if os.path.exists(checkpoint_save_path + '.index'):
    print('-------------load the model_RNN-----------------')
    model_RNN.load_weights(checkpoint_save_path)

cp_callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_save_path,
                                                 save_weights_only=True,
                                                 save_best_only=True,
                                                 monitor='val_loss')

history = model_RNN.fit(x_train, y_train, batch_size=64, epochs=100, validation_data=(x_test, y_test), validation_freq=1,
                    callbacks=[cp_callback])

model_RNN.summary()
# Out:
# -------------load the model_RNN-----------------
# Train on 270 samples, validate on 45 samples
# Epoch 1/50
# 270/270 [==============================] - 2s 8ms/sample - loss: 0.0317 - val_loss: 0.0164
# Epoch 2/50
# 270/270 [==============================] - 0s 717us/sample - loss: 0.0354 - val_loss: 0.0132
# Epoch 3/50
# 270/270 [==============================] - 0s 185us/sample - loss: 0.0334 - val_loss: 0.0146
# Epoch 4/50
# 270/270 [==============================] - 0s 185us/sample - loss: 0.0301 - val_loss: 0.0163
# Epoch 5/50
# 270/270 [==============================] - 0s 182us/sample - loss: 0.0341 - val_loss: 0.0165
# Epoch 6/50
# 270/270 [==============================] - 0s 185us/sample - loss: 0.0318 - val_loss: 0.0219
# Epoch 7/50
# 270/270 [==============================] - 0s 185us/sample - loss: 0.0317 - val_loss: 0.0139
# Epoch 8/50
# 270/270 [==============================] - 0s 182us/sample - loss: 0.0314 - val_loss: 0.0224
# Epoch 9/50
# 270/270 [==============================] - 0s 178us/sample - loss: 0.0327 - val_loss: 0.0153
# Epoch 10/50
# 270/270 [==============================] - 0s 193us/sample - loss: 0.0288 - val_loss: 0.0186
# Epoch 11/50
# 270/270 [==============================] - 0s 185us/sample - loss: 0.0361 - val_loss: 0.0195
# Epoch 12/50
# 270/270 [==============================] - 0s 178us/sample - loss: 0.0312 - val_loss: 0.0136
# Epoch 13/50
# 270/270 [==============================] - 0s 181us/sample - loss: 0.0281 - val_loss: 0.0244
# Epoch 14/50
# 270/270 [==============================] - 0s 193us/sample - loss: 0.0305 - val_loss: 0.0152
# Epoch 15/50
# 270/270 [==============================] - 0s 196us/sample - loss: 0.0324 - val_loss: 0.0167
# Epoch 16/50
# 270/270 [==============================] - 0s 204us/sample - loss: 0.0304 - val_loss: 0.0205
# Epoch 17/50
# 270/270 [==============================] - 0s 211us/sample - loss: 0.0305 - val_loss: 0.0146
# Epoch 18/50
# 270/270 [==============================] - 0s 215us/sample - loss: 0.0299 - val_loss: 0.0237
# Epoch 19/50
# 270/270 [==============================] - 0s 204us/sample - loss: 0.0301 - val_loss: 0.0167
# Epoch 20/50
# 270/270 [==============================] - 0s 215us/sample - loss: 0.0280 - val_loss: 0.0164
# Epoch 21/50
# 270/270 [==============================] - 0s 207us/sample - loss: 0.0285 - val_loss: 0.0200
# Epoch 22/50
# 270/270 [==============================] - 0s 207us/sample - loss: 0.0309 - val_loss: 0.0152
# Epoch 23/50
# 270/270 [==============================] - 0s 211us/sample - loss: 0.0279 - val_loss: 0.0222
# Epoch 24/50
# 270/270 [==============================] - 0s 226us/sample - loss: 0.0271 - val_loss: 0.0189
# Epoch 25/50
# 270/270 [==============================] - 0s 211us/sample - loss: 0.0291 - val_loss: 0.0177
# Epoch 26/50
# 270/270 [==============================] - 0s 193us/sample - loss: 0.0295 - val_loss: 0.0167
# Epoch 27/50
# 270/270 [==============================] - 0s 185us/sample - loss: 0.0276 - val_loss: 0.0202
# Epoch 28/50
# 270/270 [==============================] - 0s 185us/sample - loss: 0.0304 - val_loss: 0.0149
# Epoch 29/50
# 270/270 [==============================] - 0s 189us/sample - loss: 0.0269 - val_loss: 0.0137
# Epoch 30/50
# 270/270 [==============================] - 0s 189us/sample - loss: 0.0294 - val_loss: 0.0178
# Epoch 31/50
# 270/270 [==============================] - 0s 189us/sample - loss: 0.0281 - val_loss: 0.0143
# Epoch 32/50
# 270/270 [==============================] - 0s 178us/sample - loss: 0.0279 - val_loss: 0.0157
# Epoch 33/50
# 270/270 [==============================] - 0s 178us/sample - loss: 0.0309 - val_loss: 0.0162
# Epoch 34/50
# 270/270 [==============================] - 0s 181us/sample - loss: 0.0283 - val_loss: 0.0175
# Epoch 35/50
# 270/270 [==============================] - 0s 174us/sample - loss: 0.0313 - val_loss: 0.0179
# Epoch 36/50
# 270/270 [==============================] - 0s 178us/sample - loss: 0.0335 - val_loss: 0.0173
# Epoch 37/50
# 270/270 [==============================] - 0s 189us/sample - loss: 0.0282 - val_loss: 0.0157
# Epoch 38/50
# 270/270 [==============================] - 0s 178us/sample - loss: 0.0324 - val_loss: 0.0156
# Epoch 39/50
# 270/270 [==============================] - 0s 189us/sample - loss: 0.0321 - val_loss: 0.0218
# Epoch 40/50
# 270/270 [==============================] - 0s 178us/sample - loss: 0.0325 - val_loss: 0.0145
# Epoch 41/50
# 270/270 [==============================] - 0s 178us/sample - loss: 0.0290 - val_loss: 0.0153
# Epoch 42/50
# 270/270 [==============================] - 0s 189us/sample - loss: 0.0280 - val_loss: 0.0143
# Epoch 43/50
# 270/270 [==============================] - 0s 185us/sample - loss: 0.0341 - val_loss: 0.0169
# Epoch 44/50
# 270/270 [==============================] - 0s 193us/sample - loss: 0.0324 - val_loss: 0.0184
# Epoch 45/50
# 270/270 [==============================] - 0s 178us/sample - loss: 0.0279 - val_loss: 0.0140
# Epoch 46/50
# 270/270 [==============================] - 0s 178us/sample - loss: 0.0378 - val_loss: 0.0214
# Epoch 47/50
# 270/270 [==============================] - 0s 174us/sample - loss: 0.0352 - val_loss: 0.0153
# Epoch 48/50
# 270/270 [==============================] - 0s 200us/sample - loss: 0.0315 - val_loss: 0.0166
# Epoch 49/50
# 270/270 [==============================] - 0s 181us/sample - loss: 0.0333 - val_loss: 0.0208
# Epoch 50/50
# 270/270 [==============================] - 0s 178us/sample - loss: 0.0301 - val_loss: 0.0143
# Model: "sequential_12"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# simple_rnn_22 (SimpleRNN)    multiple                  8560
# _________________________________________________________________
# dropout_24 (Dropout)         multiple                  0
# _________________________________________________________________
# simple_rnn_23 (SimpleRNN)    multiple                  18100
# _________________________________________________________________
# dropout_25 (Dropout)         multiple                  0
# _________________________________________________________________
# dense_18 (Dense)             multiple                  101
# =================================================================
# Total params: 26,761
# Trainable params: 26,761
# Non-trainable params: 0
# _________________________________________________________________

# %%
file = open('C:/Users/Administrator/Desktop/RNN_RON_LOSS_weights.txt', 'w' )  # 参数提取
for v in model_RNN.trainable_variables:
    file.write(str(v.name) + '\n')
    file.write(str(v.shape) + '\n')
    file.write(str(v.numpy()) + '\n')
file.close()

loss = history.history['loss']
val_loss = history.history['val_loss']

plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.title(' RNN of Training and Validation Loss')
plt.legend()
#plt.show()
plt.savefig(r"C:\Users\Administrator\Desktop\RNN_Loss.jpg")

# %%
 #####看图######
################## predict ######################
# 测试集输入模型进行预测
predicted_RON_LOSS = model_RNN.predict(x_test)
# 对预测数据还原---从（0，1）反归一化到原始范围
predicted_RON_LOSS = sc_y.inverse_transform(predicted_RON_LOSS)
# 对真实数据还原---从（0，1）反归一化到原始范围
real_RON_LOSS = sc_y.inverse_transform(y_test)
# 画出真实数据和预测数据的对比曲线
plt.plot(real_RON_LOSS, color='red', label=' realed RON LOSS')
plt.plot(predicted_RON_LOSS, color='blue', label=' RNN of Predicted RON LOSS')
plt.title(' RNN of RON LOSS Prediction')
plt.xlabel('Time')
plt.ylabel('RON LOSS')
plt.legend()
#plt.show()
plt.savefig(r"C:\Users\Administrator\Desktop\RNN_predict.jpg")

# %%
##########evaluate##############
# calculate MSE 均方误差 ---> E[(预测值-真实值)^2] (预测值减真实值求平方后求均值)
mse = mean_squared_error(predicted_RON_LOSS, real_RON_LOSS)
# calculate RMSE 均方根误差--->sqrt[MSE]    (对均方误差开方)
rmse = math.sqrt(mean_squared_error(predicted_RON_LOSS, real_RON_LOSS))
# calculate MAE 平均绝对误差----->E[|预测值-真实值|](预测值减真实值求绝对值后求均值）
mae = mean_absolute_error(predicted_RON_LOSS, real_RON_LOSS)
print('均方误差: %.6f' % mse)
print('均方根误差: %.6f' % rmse)
print('平均绝对误差: %.6f' % mae)
# Out:
# 均方误差: 0.036696
# 均方根误差: 0.191562
# 平均绝对误差: 0.154711

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.layers import Dropout, Dense, LSTM
import matplotlib.pyplot as plt
import os
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error
import math



data = pd.read_csv(r"C:\Users\Administrator\Desktop\x_fe_poly.csv")
data = data.sort_values('id', ascending = False)


training_set = data.iloc[0:325 - 50, : ].values  #  前(325-50=275)天的数据作为训练集,表格从0开始计数
test_set = data.iloc[325 - 50: , : ].values  # 后50天的数据作为测试集

# 归一化
sc_x = MinMaxScaler(feature_range=(0, 1))  # 定义归一化：归一化到(0，1)之间
sc_y = MinMaxScaler(feature_range=(0, 1))  # 定义归一化：归一化到(0，1)之间
training_set_scaled_x = sc_x.fit_transform(training_set[:,2:])  # 求得训练集的最大值，最小值这些训练集固有的属性，并在训练集上进行归一化
training_set_scaled_y = sc_y.fit_transform(training_set[:,1:2])  # 求得训练集的最大值，最小值这些训练集固有的属性，并在训练集上进行归一化
test_set_x = sc_x.transform(test_set[:,2:])  # 利用训练集的属性对测试集进行归一化
test_set_y = sc_y.transform(test_set[:,1:2])  # 利用训练集的属性对测试集进行归一化

x_train = []
y_train = []

x_test = []
y_test = []


# 测试集：csv表格中前325-50=275个数据
# 利用for循环，遍历整个训练集，提取训练集中连续5天的26个降维新变量作为输入特征x_train，第6天的RON_LOSS作为标签，for循环共构建325-50-5=270组数据。

for i in range(5, len(training_set_scaled_x)):
    x_train.append(training_set_scaled_x[i - 5:i, :])
    y_train.append(training_set_scaled_y[i, :])
# 对训练集进行打乱
np.random.seed(7)
np.random.shuffle(x_train)
np.random.seed(7)
np.random.shuffle(y_train)
tf.random.set_seed(7)
# 将训练集由list格式变为array格式
x_train, y_train = np.array(x_train), np.array(y_train)

# 使x_train符合RNN输入要求：[送入样本数， 循环核时间展开步数， 每个时间步输入特征个数]。
# 此处整个数据集送入，送入样本数为x_train.shape[0]即270组数据；输入连续5个的26个降维新变量，预测出第6天的RON_LOSS，循环核时间展开步数为5; 每个时间步送入的特征是连续5天的26个降维新变量，有26个数据，故每个时间步输入特征个数为26
x_train = np.reshape(x_train, (x_train.shape[0], 5, 26))
# 测试集：csv表格中后50天数据
# 利用for循环，遍历整个测试集，提取测试集中连续5天的26个降维新变量作为输入特征x_train，第6天的数据作为RON_LOSS，for循环共构建50-5=45组数据。
for i in range(5, len(test_set_x)):
    x_test.append(test_set_x[i - 5 : i, :])
    y_test.append(test_set_y[i, :])
# 测试集变array并reshape为符合RNN输入要求：[送入样本数， 循环核时间展开步数， 每个时间步输入特征个数]
x_test, y_test = np.array(x_test), np.array(y_test)
x_test = np.reshape(x_test, (x_test.shape[0], 5, 26))


model_LSTM = tf.keras.Sequential([
    LSTM(80, return_sequences=True),
    Dropout(0.2),
    LSTM(100),
    Dropout(0.2),
    Dense(1)
])

model_LSTM.compile(optimizer=tf.keras.optimizers.Adam(0.001),
              loss='mean_squared_error')  # 损失函数用均方误差
# 该应用只观测loss数值，不观测准确率，所以删去metrics选项，一会在每个epoch迭代显示时只显示loss值
#C:\Users\Administrator\Desktop\
checkpoint_save_path = r"C:\Users\Administrator\Desktop\LSTMcheckpoint\LSTM_RON_LOSS.ckpt"

if os.path.exists(checkpoint_save_path + '.index'):
    print('-------------load the model_LSTM-----------------')
    model_LSTM.load_weights(checkpoint_save_path)

cp_callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_save_path,
                                                 save_weights_only=True,
                                                 save_best_only=True,
                                                 monitor='val_loss')

history = model_LSTM.fit(x_train, y_train, batch_size=64, epochs=50, validation_data=(x_test, y_test), validation_freq=1,
                    callbacks=[cp_callback])

model_LSTM.summary()
# Out:
# Train on 270 samples, validate on 45 samples
# Epoch 1/50
# 270/270 [==============================] - 5s 20ms/sample - loss: 0.2227 - val_loss: 0.0287
# Epoch 2/50
# 270/270 [==============================] - 0s 906us/sample - loss: 0.0793 - val_loss: 0.0244
# Epoch 3/50
# 270/270 [==============================] - 0s 300us/sample - loss: 0.0386 - val_loss: 0.0373
# Epoch 4/50
# 270/270 [==============================] - 0s 300us/sample - loss: 0.0470 - val_loss: 0.0298
# Epoch 5/50
# 270/270 [==============================] - 0s 928us/sample - loss: 0.0323 - val_loss: 0.0146
# Epoch 6/50
# 270/270 [==============================] - 0s 307us/sample - loss: 0.0310 - val_loss: 0.0156
# Epoch 7/50
# 270/270 [==============================] - 0s 311us/sample - loss: 0.0280 - val_loss: 0.0157
# Epoch 8/50
# 270/270 [==============================] - 0s 333us/sample - loss: 0.0266 - val_loss: 0.0194
# Epoch 9/50
# 270/270 [==============================] - 0s 333us/sample - loss: 0.0260 - val_loss: 0.0168
# Epoch 10/50
# 270/270 [==============================] - 0s 1ms/sample - loss: 0.0244 - val_loss: 0.0145
# Epoch 11/50
# 270/270 [==============================] - 0s 385us/sample - loss: 0.0244 - val_loss: 0.0157
# Epoch 12/50
# 270/270 [==============================] - 0s 370us/sample - loss: 0.0231 - val_loss: 0.0172
# Epoch 13/50
# 270/270 [==============================] - 0s 389us/sample - loss: 0.0238 - val_loss: 0.0154
# Epoch 14/50
# 270/270 [==============================] - 0s 326us/sample - loss: 0.0217 - val_loss: 0.0154
# Epoch 15/50
# 270/270 [==============================] - 0s 304us/sample - loss: 0.0232 - val_loss: 0.0177
# Epoch 16/50
# 270/270 [==============================] - 0s 307us/sample - loss: 0.0219 - val_loss: 0.0159
# Epoch 17/50
# 270/270 [==============================] - 0s 307us/sample - loss: 0.0214 - val_loss: 0.0165
# Epoch 18/50
# 270/270 [==============================] - 0s 307us/sample - loss: 0.0216 - val_loss: 0.0165
# Epoch 19/50
# 270/270 [==============================] - 0s 307us/sample - loss: 0.0205 - val_loss: 0.0171
# Epoch 20/50
# 270/270 [==============================] - 0s 304us/sample - loss: 0.0211 - val_loss: 0.0173
# Epoch 21/50
# 270/270 [==============================] - 0s 315us/sample - loss: 0.0206 - val_loss: 0.0169
# Epoch 22/50
# 270/270 [==============================] - 0s 311us/sample - loss: 0.0203 - val_loss: 0.0185
# Epoch 23/50
# 270/270 [==============================] - 0s 315us/sample - loss: 0.0217 - val_loss: 0.0181
# Epoch 24/50
# 270/270 [==============================] - 0s 304us/sample - loss: 0.0210 - val_loss: 0.0170
# Epoch 25/50
# 270/270 [==============================] - 0s 311us/sample - loss: 0.0206 - val_loss: 0.0177
# Epoch 26/50
# 270/270 [==============================] - 0s 315us/sample - loss: 0.0208 - val_loss: 0.0174
# Epoch 27/50
# 270/270 [==============================] - 0s 311us/sample - loss: 0.0191 - val_loss: 0.0172
# Epoch 28/50
# 270/270 [==============================] - 0s 315us/sample - loss: 0.0227 - val_loss: 0.0187
# Epoch 29/50
# 270/270 [==============================] - 0s 307us/sample - loss: 0.0204 - val_loss: 0.0182
# Epoch 30/50
# 270/270 [==============================] - 0s 311us/sample - loss: 0.0202 - val_loss: 0.0175
# Epoch 31/50
# 270/270 [==============================] - 0s 326us/sample - loss: 0.0210 - val_loss: 0.0186
# Epoch 32/50
# 270/270 [==============================] - 0s 311us/sample - loss: 0.0189 - val_loss: 0.0174
# Epoch 33/50
# 270/270 [==============================] - 0s 307us/sample - loss: 0.0207 - val_loss: 0.0186
# Epoch 34/50
# 270/270 [==============================] - 0s 304us/sample - loss: 0.0188 - val_loss: 0.0194
# Epoch 35/50
# 270/270 [==============================] - 0s 315us/sample - loss: 0.0209 - val_loss: 0.0194
# Epoch 36/50
# 270/270 [==============================] - ETA: 0s - loss: 0.021 - 0s 319us/sample - loss: 0.0201 - val_loss: 0.0184
# Epoch 37/50
# 270/270 [==============================] - 0s 322us/sample - loss: 0.0192 - val_loss: 0.0181
# Epoch 38/50
# 270/270 [==============================] - 0s 319us/sample - loss: 0.0200 - val_loss: 0.0178
# Epoch 39/50
# 270/270 [==============================] - 0s 307us/sample - loss: 0.0197 - val_loss: 0.0192
# Epoch 40/50
# 270/270 [==============================] - 0s 393us/sample - loss: 0.0203 - val_loss: 0.0193
# Epoch 41/50
# 270/270 [==============================] - 0s 367us/sample - loss: 0.0208 - val_loss: 0.0182
# Epoch 42/50
# 270/270 [==============================] - 0s 356us/sample - loss: 0.0212 - val_loss: 0.0225
# Epoch 43/50
# 270/270 [==============================] - 0s 344us/sample - loss: 0.0216 - val_loss: 0.0183
# Epoch 44/50
# 270/270 [==============================] - 0s 393us/sample - loss: 0.0192 - val_loss: 0.0228
# Epoch 45/50
# 270/270 [==============================] - 0s 359us/sample - loss: 0.0203 - val_loss: 0.0191
# Epoch 46/50
# 270/270 [==============================] - 0s 322us/sample - loss: 0.0204 - val_loss: 0.0207
# Epoch 47/50
# 270/270 [==============================] - 0s 311us/sample - loss: 0.0219 - val_loss: 0.0210
# Epoch 48/50
# 270/270 [==============================] - 0s 304us/sample - loss: 0.0196 - val_loss: 0.0184
# Epoch 49/50
# 270/270 [==============================] - 0s 311us/sample - loss: 0.0199 - val_loss: 0.0287
# Epoch 50/50
# 270/270 [==============================] - 0s 307us/sample - loss: 0.0221 - val_loss: 0.0182
# Model: "sequential_11"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm (LSTM)                  multiple                  34240
# _________________________________________________________________
# dropout_22 (Dropout)         multiple                  0
# _________________________________________________________________
# lstm_1 (LSTM)                multiple                  72400
# _________________________________________________________________
# dropout_23 (Dropout)         multiple                  0
# _________________________________________________________________
# dense_17 (Dense)             multiple                  101
# =================================================================
# Total params: 106,741
# Trainable params: 106,741
# Non-trainable params: 0
# _________________________________________________________________

# %%
file = open('C:/Users/Administrator/Desktop/LSTM_RON_LOSS_weights.txt', 'w' )  # 参数提取
for v in model_LSTM.trainable_variables:
    file.write(str(v.name) + '\n')
    file.write(str(v.shape) + '\n')
    file.write(str(v.numpy()) + '\n')
file.close()

loss = history.history['loss']
val_loss = history.history['val_loss']

plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.title(' LSTM of Training and Validation Loss')
plt.legend()
#plt.show()
plt.savefig(r"C:\Users\Administrator\Desktop\LSTM_Loss.jpg")

# %%
################## predict ######################
# 测试集输入模型进行预测
predicted_RON_LOSS = model_LSTM.predict(x_test)
# 对预测数据还原---从（0，1）反归一化到原始范围
predicted_RON_LOSS = sc_y.inverse_transform(predicted_RON_LOSS)
# 对真实数据还原---从（0，1）反归一化到原始范围
real_RON_LOSS = sc_y.inverse_transform(y_test)
# 画出真实数据和预测数据的对比曲线
plt.plot(real_RON_LOSS, color='red', label=' realed RON LOSS')
plt.plot(predicted_RON_LOSS, color='blue', label='LSTM of Predicted RON LOSS')
plt.title(' LSTM of RON LOSS Prediction')
plt.xlabel('Time')
plt.ylabel('RON LOSS')
plt.legend()
#plt.show()
plt.savefig(r"C:\Users\Administrator\Desktop\LSTM_predict.jpg")

# %%
##########evaluate##############
# calculate MSE 均方误差 ---> E[(预测值-真实值)^2] (预测值减真实值求平方后求均值)
mse = mean_squared_error(predicted_RON_LOSS, real_RON_LOSS)
# calculate RMSE 均方根误差--->sqrt[MSE]    (对均方误差开方)
rmse = math.sqrt(mean_squared_error(predicted_RON_LOSS, real_RON_LOSS))
# calculate MAE 平均绝对误差----->E[|预测值-真实值|](预测值减真实值求绝对值后求均值）
mae = mean_absolute_error(predicted_RON_LOSS, real_RON_LOSS)
print('均方误差: %.6f' % mse)
print('均方根误差: %.6f' % rmse)
print('平均绝对误差: %.6f' % mae)
# Out:
# 均方误差: 0.046713
# 均方根误差: 0.216131
# 平均绝对误差: 0.182945

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.layers import Dropout, Dense, GRU
import matplotlib.pyplot as plt
import os
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error
import math


data = pd.read_csv(r"C:\Users\Administrator\Desktop\x_fe_poly.csv")
data = data.sort_values('id', ascending = False)


training_set = data.iloc[0:325 - 50, : ].values  #  #  前(325-50=275)天的数据作为训练集,表格从0开始计数
test_set = data.iloc[325 - 50: , : ].values  # 后50天的数据作为测试集

# 归一化
sc_x = MinMaxScaler(feature_range=(0, 1))  # 定义归一化：归一化到(0，1)之间
sc_y = MinMaxScaler(feature_range=(0, 1))  # 定义归一化：归一化到(0，1)之间
training_set_scaled_x = sc_x.fit_transform(training_set[:,2:])  # 求得训练集的最大值，最小值这些训练集固有的属性，并在训练集上进行归一化
training_set_scaled_y = sc_y.fit_transform(training_set[:,1:2])  # 求得训练集的最大值，最小值这些训练集固有的属性，并在训练集上进行归一化
test_set_x = sc_x.transform(test_set[:,2:])  # 利用训练集的属性对测试集进行归一化
test_set_y = sc_y.transform(test_set[:,1:2])  # 利用训练集的属性对测试集进行归一化

x_train = []
y_train = []

x_test = []
y_test = []

# 测试集：csv表格中前325-50=275个数据
# 利用for循环，遍历整个训练集，提取训练集中连续5天的26个降维新变量作为输入特征x_train，第6天的RON_LOSS作为标签，for循环共构建325-50-5=270组数据。

for i in range(5, len(training_set_scaled_x)):
    x_train.append(training_set_scaled_x[i - 5:i, :])
    y_train.append(training_set_scaled_y[i, :])
# 对训练集进行打乱
np.random.seed(7)
np.random.shuffle(x_train)
np.random.seed(7)
np.random.shuffle(y_train)
tf.random.set_seed(7)
# 将训练集由list格式变为array格式
x_train, y_train = np.array(x_train), np.array(y_train)

# 使x_train符合RNN输入要求：[送入样本数， 循环核时间展开步数， 每个时间步输入特征个数]。
# 此处整个数据集送入，送入样本数为x_train.shape[0]即270组数据；输入连续5个的26个降维新变量，预测出第6天的RON_LOSS，循环核时间展开步数为5; 每个时间步送入的特征是连续5天的26个降维新变量，有26个数据，故每个时间步输入特征个数为26
x_train = np.reshape(x_train, (x_train.shape[0], 5, 26))
# 测试集：csv表格中后50天数据
# 利用for循环，遍历整个测试集，提取测试集中连续5天的26个降维新变量作为输入特征x_train，第6天的RON_LOSS作为标签，for循环共构建50-5=45组数据。
for i in range(5, len(test_set_x)):
    x_test.append(test_set_x[i - 5 : i, :])
    y_test.append(test_set_y[i, :])
# 测试集变array并reshape为符合RNN输入要求：[送入样本数， 循环核时间展开步数， 每个时间步输入特征个数]
x_test, y_test = np.array(x_test), np.array(y_test)
x_test = np.reshape(x_test, (x_test.shape[0], 5, 26))

model_GRU = tf.keras.Sequential([
    GRU(80, return_sequences=True),
    Dropout(0.2),
    GRU(100),
    Dropout(0.2),
    Dense(1)
])

model_GRU.compile(optimizer=tf.keras.optimizers.Adam(0.001),
              loss='mean_squared_error')  # 损失函数用均方误差
# 该应用只观测loss数值，不观测准确率，所以删去metrics选项，一会在每个epoch迭代显示时只显示loss值
#C:\Users\Administrator\Desktop\
checkpoint_save_path = r"C:\Users\Administrator\Desktop\GRUcheckpoint\GRU_RON_LOSS.ckpt"

if os.path.exists(checkpoint_save_path + '.index'):
    print('-------------load the model_GRU-----------------')
    model_GRU.load_weights(checkpoint_save_path)

cp_callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_save_path,
                                                 save_weights_only=True,
                                                 save_best_only=True,
                                                 monitor='val_loss')

history = model_GRU.fit(x_train, y_train, batch_size=64, epochs=50, validation_data=(x_test, y_test), validation_freq=1,
                    callbacks=[cp_callback])

model_GRU.summary()
# Out:
# Train on 270 samples, validate on 45 samples
# Epoch 1/50
# 270/270 [==============================] - 6s 21ms/sample - loss: 0.1882 - val_loss: 0.1021
# Epoch 2/50
# 270/270 [==============================] - 0s 1ms/sample - loss: 0.1085 - val_loss: 0.0313
# Epoch 3/50
# 270/270 [==============================] - 0s 297us/sample - loss: 0.0586 - val_loss: 0.0766
# Epoch 4/50
# 270/270 [==============================] - 0s 1ms/sample - loss: 0.0486 - val_loss: 0.0192
# Epoch 5/50
# 270/270 [==============================] - 0s 352us/sample - loss: 0.0397 - val_loss: 0.0193
# Epoch 6/50
# 270/270 [==============================] - 0s 348us/sample - loss: 0.0379 - val_loss: 0.0250
# Epoch 7/50
# 270/270 [==============================] - 0s 359us/sample - loss: 0.0329 - val_loss: 0.0359
# Epoch 8/50
# 270/270 [==============================] - 0s 537us/sample - loss: 0.0304 - val_loss: 0.0221
# Epoch 9/50
# 270/270 [==============================] - 0s 1ms/sample - loss: 0.0271 - val_loss: 0.0189
# Epoch 10/50
# 270/270 [==============================] - 0s 407us/sample - loss: 0.0250 - val_loss: 0.0225
# Epoch 11/50
# 270/270 [==============================] - 0s 352us/sample - loss: 0.0242 - val_loss: 0.0320
# Epoch 12/50
# 270/270 [==============================] - 0s 382us/sample - loss: 0.0264 - val_loss: 0.0252
# Epoch 13/50
# 270/270 [==============================] - 0s 356us/sample - loss: 0.0270 - val_loss: 0.0215
# Epoch 14/50
# 270/270 [==============================] - 0s 304us/sample - loss: 0.0232 - val_loss: 0.0269
# Epoch 15/50
# 270/270 [==============================] - 0s 300us/sample - loss: 0.0229 - val_loss: 0.0268
# Epoch 16/50
# 270/270 [==============================] - 0s 300us/sample - loss: 0.0259 - val_loss: 0.0229
# Epoch 17/50
# 270/270 [==============================] - 0s 293us/sample - loss: 0.0208 - val_loss: 0.0258
# Epoch 18/50
# 270/270 [==============================] - 0s 289us/sample - loss: 0.0211 - val_loss: 0.0233
# Epoch 19/50
# 270/270 [==============================] - 0s 289us/sample - loss: 0.0217 - val_loss: 0.0235
# Epoch 20/50
# 270/270 [==============================] - 0s 285us/sample - loss: 0.0220 - val_loss: 0.0270
# Epoch 21/50
# 270/270 [==============================] - 0s 282us/sample - loss: 0.0235 - val_loss: 0.0224
# Epoch 22/50
# 270/270 [==============================] - 0s 293us/sample - loss: 0.0212 - val_loss: 0.0253
# Epoch 23/50
# 270/270 [==============================] - 0s 296us/sample - loss: 0.0207 - val_loss: 0.0265
# Epoch 24/50
# 270/270 [==============================] - 0s 330us/sample - loss: 0.0223 - val_loss: 0.0244
# Epoch 25/50
# 270/270 [==============================] - 0s 396us/sample - loss: 0.0214 - val_loss: 0.0227
# Epoch 26/50
# 270/270 [==============================] - 0s 330us/sample - loss: 0.0206 - val_loss: 0.0237
# Epoch 27/50
# 270/270 [==============================] - 0s 359us/sample - loss: 0.0212 - val_loss: 0.0230
# Epoch 28/50
# 270/270 [==============================] - 0s 352us/sample - loss: 0.0212 - val_loss: 0.0250
# Epoch 29/50
# 270/270 [==============================] - 0s 337us/sample - loss: 0.0218 - val_loss: 0.0253
# Epoch 30/50
# 270/270 [==============================] - 0s 319us/sample - loss: 0.0210 - val_loss: 0.0217
# Epoch 31/50
# 270/270 [==============================] - 0s 304us/sample - loss: 0.0235 - val_loss: 0.0256
# Epoch 32/50
# 270/270 [==============================] - 0s 307us/sample - loss: 0.0222 - val_loss: 0.0263
# Epoch 33/50
# 270/270 [==============================] - 0s 296us/sample - loss: 0.0234 - val_loss: 0.0247
# Epoch 34/50
# 270/270 [==============================] - 0s 289us/sample - loss: 0.0203 - val_loss: 0.0298
# Epoch 35/50
# 270/270 [==============================] - 0s 293us/sample - loss: 0.0204 - val_loss: 0.0281
# Epoch 36/50
# 270/270 [==============================] - 0s 319us/sample - loss: 0.0206 - val_loss: 0.0270
# Epoch 37/50
# 270/270 [==============================] - 0s 367us/sample - loss: 0.0191 - val_loss: 0.0286
# Epoch 38/50
# 270/270 [==============================] - 0s 356us/sample - loss: 0.0204 - val_loss: 0.0237
# Epoch 39/50
# 270/270 [==============================] - 0s 344us/sample - loss: 0.0217 - val_loss: 0.0302
# Epoch 40/50
# 270/270 [==============================] - 0s 385us/sample - loss: 0.0215 - val_loss: 0.0290
# Epoch 41/50
# 270/270 [==============================] - 0s 393us/sample - loss: 0.0224 - val_loss: 0.0271
# Epoch 42/50
# 270/270 [==============================] - 0s 333us/sample - loss: 0.0199 - val_loss: 0.0300
# Epoch 43/50
# 270/270 [==============================] - 0s 315us/sample - loss: 0.0211 - val_loss: 0.0267
# Epoch 44/50
# 270/270 [==============================] - 0s 307us/sample - loss: 0.0181 - val_loss: 0.0340
# Epoch 45/50
# 270/270 [==============================] - 0s 311us/sample - loss: 0.0197 - val_loss: 0.0259
# Epoch 46/50
# 270/270 [==============================] - 0s 315us/sample - loss: 0.0228 - val_loss: 0.0316
# Epoch 47/50
# 270/270 [==============================] - 0s 315us/sample - loss: 0.0211 - val_loss: 0.0297
# Epoch 48/50
# 270/270 [==============================] - 0s 307us/sample - loss: 0.0228 - val_loss: 0.0246
# Epoch 49/50
# 270/270 [==============================] - 0s 307us/sample - loss: 0.0181 - val_loss: 0.0356
# Epoch 50/50
# 270/270 [==============================] - 0s 326us/sample - loss: 0.0226 - val_loss: 0.0247
# Model: "sequential_13"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# gru (GRU)                    multiple                  25920
# _________________________________________________________________
# dropout_26 (Dropout)         multiple                  0
# _________________________________________________________________
# gru_1 (GRU)                  multiple                  54600
# _________________________________________________________________
# dropout_27 (Dropout)         multiple                  0
# _________________________________________________________________
# dense_19 (Dense)             multiple                  101
# =================================================================
# Total params: 80,621
# Trainable params: 80,621
# Non-trainable params: 0
# _________________________________________________________________

# %%
file = open('C:/Users/Administrator/Desktop/GRU_RON_LOSS_weights.txt', 'w' )  # 参数提取
for v in model_GRU.trainable_variables:
    file.write(str(v.name) + '\n')
    file.write(str(v.shape) + '\n')
    file.write(str(v.numpy()) + '\n')
file.close()

loss = history.history['loss']
val_loss = history.history['val_loss']

plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.title(' GRU of Training and Validation Loss')
plt.legend()
#plt.show()
plt.savefig(r"C:\Users\Administrator\Desktop\GRU_Loss.jpg")

# %%
################## predict ######################
# 测试集输入模型进行预测
predicted_RON_LOSS = model_GRU.predict(x_test)
# 对预测数据还原---从（0，1）反归一化到原始范围
predicted_RON_LOSS = sc_y.inverse_transform(predicted_RON_LOSS)
# 对真实数据还原---从（0，1）反归一化到原始范围
real_RON_LOSS = sc_y.inverse_transform(y_test)
# 画出真实数据和预测数据的对比曲线
plt.plot(real_RON_LOSS, color='red', label=' realed RON LOSS')
plt.plot(predicted_RON_LOSS, color='blue', label=' GRU of Predicted RON LOSS')
plt.title('GRU of RON LOSS Prediction')
plt.xlabel('Time')
plt.ylabel('RON LOSS')
plt.legend()
#plt.show()
plt.savefig(r"C:\Users\Administrator\Desktop\GRU_Lpredict.jpg")

# %%
##########evaluate##############
# calculate MSE 均方误差 ---> E[(预测值-真实值)^2] (预测值减真实值求平方后求均值)
mse = mean_squared_error(predicted_RON_LOSS, real_RON_LOSS)
# calculate RMSE 均方根误差--->sqrt[MSE]    (对均方误差开方)
rmse = math.sqrt(mean_squared_error(predicted_RON_LOSS, real_RON_LOSS))
# calculate MAE 平均绝对误差----->E[|预测值-真实值|](预测值减真实值求绝对值后求均值）
mae = mean_absolute_error(predicted_RON_LOSS, real_RON_LOSS)
print('均方误差: %.6f' % mse)
print('均方根误差: %.6f' % rmse)
print('平均绝对误差: %.6f' % mae)
# Out:
# 均方误差: 0.063145
# 均方根误差: 0.251287
# 平均绝对误差: 0.203883

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.layers import Dropout, Dense, SimpleRNN
import matplotlib.pyplot as plt
import os
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error
import math
data = pd.read_csv(r"C:\Users\Administrator\Desktop\x_fe_poly.csv")
data = data.sort_values('id', ascending = False)


training_set = data.iloc[0:325 - 50, : ].values  # 前(325-50=275)天的数据作为训练集,表格从0开始计数
test_set = data.iloc[325 - 50: , : ].values  # 后50天的数据作为测试集

# 归一化
sc_x = MinMaxScaler(feature_range=(0, 1))  # 定义归一化：归一化到(0，1)之间
sc_y = MinMaxScaler(feature_range=(0, 1))  # 定义归一化：归一化到(0，1)之间
training_set_scaled_x = sc_x.fit_transform(training_set[:,2:])  # 求得训练集的最大值，最小值这些训练集固有的属性，并在训练集上进行归一化
training_set_scaled_y = sc_y.fit_transform(training_set[:,1:2])  # 求得训练集的最大值，最小值这些训练集固有的属性，并在训练集上进行归一化
test_set_x = sc_x.transform(test_set[:,2:])  # 利用训练集的属性对测试集进行归一化
test_set_y = sc_y.transform(test_set[:,1:2])  # 利用训练集的属性对测试集进行归一化

x_train = []
y_train = []

x_test = []
y_test = []

# 测试集：csv表格中前325-50=275个数据
# 利用for循环，遍历整个训练集，提取训练集中连续5天的26个降维新变量作为输入特征x_train，第6天的RON_LOSS作为标签，for循环共构建325-50-5=270组数据。

for i in range(5, len(training_set_scaled_x)):
    x_train.append(training_set_scaled_x[i - 5:i, :])
    y_train.append(training_set_scaled_y[i, :])
# 对训练集进行打乱
np.random.seed(7)
np.random.shuffle(x_train)
np.random.seed(7)
np.random.shuffle(y_train)
tf.random.set_seed(7)
# 将训练集由list格式变为array格式
x_train, y_train = np.array(x_train), np.array(y_train)

# 使x_train符合RNN输入要求：[送入样本数， 循环核时间展开步数， 每个时间步输入特征个数]。
# 此处整个数据集送入，送入样本数为x_train.shape[0]即270组数据；输入连续5个的26个降维新变量，预测出第6天的RON_LOSS，循环核时间展开步数为5; 每个时间步送入的特征是连续5天的26个降维新变量，有26个数据，故每个时间步输入特征个数为26
x_train = np.reshape(x_train, (x_train.shape[0], 5, 26))
# 测试集：csv表格中后50天数据
# 利用for循环，遍历整个测试集，提取测试集中连续5天的26个降维新变量作为输入特征x_train，第6天的数据作为RON_LOSS，for循环共构建50-5=45组数据。
for i in range(5, len(test_set_x)):
    x_test.append(test_set_x[i - 5 : i, :])
    y_test.append(test_set_y[i, :])
# 测试集变array并reshape为符合RNN输入要求：[送入样本数， 循环核时间展开步数， 每个时间步输入特征个数]
x_test, y_test = np.array(x_test), np.array(y_test)
x_test = np.reshape(x_test, (x_test.shape[0], 5, 26))

model_RNN = tf.keras.Sequential([
    SimpleRNN(80, return_sequences=True),
    Dropout(0.2),
    SimpleRNN(100),
    Dropout(0.2),
    Dense(1)
])

model_RNN.compile(optimizer=tf.keras.optimizers.Adam(0.001),
              loss='mean_squared_error')  # 损失函数用均方误差
# 该应用只观测loss数值，不观测准确率，所以删去metrics选项，一会在每个epoch迭代显示时只显示loss值
#C:\Users\Administrator\Desktop\
checkpoint_save_path = r"C:\Users\Administrator\Desktop\RNNcheckpoint\RNN_RON_LOSS.ckpt"

if os.path.exists(checkpoint_save_path + '.index'):
    print('-------------load the model_RNN-----------------')
    model_RNN.load_weights(checkpoint_save_path)

cp_callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_save_path,
                                                 save_weights_only=True,
                                                 save_best_only=True,
                                                 monitor='val_loss')

history = model_RNN.fit(x_train, y_train, batch_size=64, epochs=100, validation_data=(x_test, y_test), validation_freq=1,
                    callbacks=[cp_callback])

model_RNN.summary()

file = open('C:/Users/Administrator/Desktop/RNN_RON_LOSS_weights.txt', 'w' )  # 参数提取
for v in model_RNN.trainable_variables:
    file.write(str(v.name) + '\n')
    file.write(str(v.shape) + '\n')
    file.write(str(v.numpy()) + '\n')
file.close()

loss = history.history['loss']
val_loss = history.history['val_loss']

plt.plot(loss, label='Training Loss')
plt.plot(val_loss, label='Validation Loss')
plt.title(' RNN of Training and Validation Loss')
plt.legend()
#plt.show()
plt.savefig(r"C:\Users\Administrator\Desktop\RNN_Loss.jpg")

path = r"C:\Users\Administrator\Desktop\RNN_Loss.jpg"
if os.path.exists(path):
    print('------------------------------')
    fig = plt.figure(figsize=[20,5] ,dpi = 250)  
    #####看图######
    ################## predict ######################
    # 测试集输入模型进行预测
    predicted_RON_LOSS = model_RNN.predict(x_test)
    # 对预测数据还原---从（0，1）反归一化到原始范围
    predicted_RON_LOSS = sc_y.inverse_transform(predicted_RON_LOSS)
    # 对真实数据还原---从（0，1）反归一化到原始范围
    real_RON_LOSS = sc_y.inverse_transform(y_test)
    # 画出真实数据和预测数据的对比曲线
    plt.plot(real_RON_LOSS, color='red', label=' realed RON LOSS')
    plt.plot(predicted_RON_LOSS, color='blue', label=' RNN of Predicted RON LOSS')
    plt.title(' RNN of RON LOSS Prediction')
    plt.xlabel('Time')
    plt.ylabel('RON LOSS')
    plt.legend()
    #plt.show()
    plt.savefig(r"C:\Users\Administrator\Desktop\RNN_predict.jpg")
# Out:
# Train on 270 samples, validate on 45 samples
# Epoch 1/100
# 270/270 [==============================] - 3s 11ms/sample - loss: 1.0966 - val_loss: 0.0743
# Epoch 2/100
# 270/270 [==============================] - 0s 200us/sample - loss: 0.7223 - val_loss: 0.1253
# Epoch 3/100
# 270/270 [==============================] - 0s 178us/sample - loss: 0.4265 - val_loss: 0.2684
# Epoch 4/100
# 270/270 [==============================] - 0s 185us/sample - loss: 0.4812 - val_loss: 0.1140
# Epoch 5/100
# 270/270 [==============================] - 0s 178us/sample - loss: 0.3383 - val_loss: 0.0757
# Epoch 6/100
# 270/270 [==============================] - 0s 811us/sample - loss: 0.2490 - val_loss: 0.0302
# Epoch 7/100
# 270/270 [==============================] - 0s 204us/sample - loss: 0.2129 - val_loss: 0.0369
# Epoch 8/100
# 270/270 [==============================] - 0s 991us/sample - loss: 0.2240 - val_loss: 0.0237
# Epoch 9/100
# 270/270 [==============================] - 0s 875us/sample - loss: 0.1949 - val_loss: 0.0234
# Epoch 10/100
# 270/270 [==============================] - 0s 200us/sample - loss: 0.2219 - val_loss: 0.0271
# Epoch 11/100
# 270/270 [==============================] - 0s 192us/sample - loss: 0.2001 - val_loss: 0.0236
# Epoch 12/100
# 270/270 [==============================] - 0s 219us/sample - loss: 0.1897 - val_loss: 0.0281
# Epoch 13/100
# 270/270 [==============================] - 0s 827us/sample - loss: 0.1677 - val_loss: 0.0220
# Epoch 14/100
# 270/270 [==============================] - 0s 222us/sample - loss: 0.1655 - val_loss: 0.0426
# Epoch 15/100
# 270/270 [==============================] - 0s 211us/sample - loss: 0.1545 - val_loss: 0.0230
# Epoch 16/100
# 270/270 [==============================] - 0s 233us/sample - loss: 0.1652 - val_loss: 0.0313
# Epoch 17/100
# 270/270 [==============================] - 0s 215us/sample - loss: 0.1735 - val_loss: 0.0301
# Epoch 18/100
# 270/270 [==============================] - 0s 211us/sample - loss: 0.1476 - val_loss: 0.0232
# Epoch 19/100
# 270/270 [==============================] - 0s 189us/sample - loss: 0.1237 - val_loss: 0.0484
# Epoch 20/100
# 270/270 [==============================] - 0s 185us/sample - loss: 0.1146 - val_loss: 0.0238
# Epoch 21/100
# 270/270 [==============================] - 0s 189us/sample - loss: 0.1457 - val_loss: 0.0372
# Epoch 22/100
# 270/270 [==============================] - 0s 178us/sample - loss: 0.1211 - val_loss: 0.0231
# Epoch 23/100
# 270/270 [==============================] - 0s 679us/sample - loss: 0.1140 - val_loss: 0.0194
# Epoch 24/100
# 270/270 [==============================] - 0s 188us/sample - loss: 0.1243 - val_loss: 0.0200
# Epoch 25/100
# 270/270 [==============================] - 0s 170us/sample - loss: 0.1047 - val_loss: 0.0197
# Epoch 26/100
# 270/270 [==============================] - 0s 196us/sample - loss: 0.0898 - val_loss: 0.0201
# Epoch 27/100
# 270/270 [==============================] - 0s 788us/sample - loss: 0.0933 - val_loss: 0.0177
# Epoch 28/100
# 270/270 [==============================] - 0s 189us/sample - loss: 0.0897 - val_loss: 0.0211
# Epoch 29/100
# 270/270 [==============================] - 0s 185us/sample - loss: 0.0914 - val_loss: 0.0264
# Epoch 30/100
# 270/270 [==============================] - 0s 189us/sample - loss: 0.0960 - val_loss: 0.0245
# Epoch 31/100
# 270/270 [==============================] - 0s 189us/sample - loss: 0.0901 - val_loss: 0.0204
# Epoch 32/100
# 270/270 [==============================] - 0s 193us/sample - loss: 0.0845 - val_loss: 0.0181
# Epoch 33/100
# 270/270 [==============================] - 0s 189us/sample - loss: 0.0832 - val_loss: 0.0269
# Epoch 34/100
# 270/270 [==============================] - 0s 1ms/sample - loss: 0.0789 - val_loss: 0.0171
# Epoch 35/100
# 270/270 [==============================] - 0s 189us/sample - loss: 0.0965 - val_loss: 0.0380
# Epoch 36/100
# 270/270 [==============================] - 0s 897us/sample - loss: 0.0844 - val_loss: 0.0166
# Epoch 37/100
# 270/270 [==============================] - 0s 189us/sample - loss: 0.0655 - val_loss: 0.0176
# Epoch 38/100
# 270/270 [==============================] - 0s 193us/sample - loss: 0.0814 - val_loss: 0.0175
# Epoch 39/100
# 270/270 [==============================] - 0s 189us/sample - loss: 0.0846 - val_loss: 0.0245
# Epoch 40/100
# 270/270 [==============================] - 0s 185us/sample - loss: 0.0866 - val_loss: 0.0181
# Epoch 41/100
# 270/270 [==============================] - 0s 828us/sample - loss: 0.0698 - val_loss: 0.0158
# Epoch 42/100
# 270/270 [==============================] - 0s 1ms/sample - loss: 0.0730 - val_loss: 0.0152
# Epoch 43/100
# 270/270 [==============================] - 0s 207us/sample - loss: 0.0843 - val_loss: 0.0253
# Epoch 44/100
# 270/270 [==============================] - 0s 204us/sample - loss: 0.0756 - val_loss: 0.0175
# Epoch 45/100
# 270/270 [==============================] - 0s 215us/sample - loss: 0.0679 - val_loss: 0.0158
# Epoch 46/100
# 270/270 [==============================] - 0s 215us/sample - loss: 0.0774 - val_loss: 0.0309
# Epoch 47/100
# 270/270 [==============================] - 0s 185us/sample - loss: 0.0729 - val_loss: 0.0176
# Epoch 48/100
# 270/270 [==============================] - 0s 185us/sample - loss: 0.0668 - val_loss: 0.0195
# Epoch 49/100
# 270/270 [==============================] - 0s 189us/sample - loss: 0.0693 - val_loss: 0.0196
# Epoch 50/100
# 270/270 [==============================] - 0s 185us/sample - loss: 0.0653 - val_loss: 0.0196
# Epoch 51/100
# 270/270 [==============================] - 0s 189us/sample - loss: 0.0727 - val_loss: 0.0191
# Epoch 52/100
# 270/270 [==============================] - 0s 189us/sample - loss: 0.0761 - val_loss: 0.0177
# Epoch 53/100
# 270/270 [==============================] - 0s 185us/sample - loss: 0.0637 - val_loss: 0.0184
# Epoch 54/100
# 270/270 [==============================] - 0s 193us/sample - loss: 0.0648 - val_loss: 0.0165
# Epoch 55/100
# 270/270 [==============================] - 0s 185us/sample - loss: 0.0655 - val_loss: 0.0248
# Epoch 56/100
# 270/270 [==============================] - 0s 178us/sample - loss: 0.0561 - val_loss: 0.0166
# Epoch 57/100
# 270/270 [==============================] - 0s 178us/sample - loss: 0.0675 - val_loss: 0.0180
# Epoch 58/100
# 270/270 [==============================] - 0s 174us/sample - loss: 0.0670 - val_loss: 0.0222
# Epoch 59/100
# 270/270 [==============================] - 0s 178us/sample - loss: 0.0554 - val_loss: 0.0159
# Epoch 60/100
# 270/270 [==============================] - 0s 182us/sample - loss: 0.0591 - val_loss: 0.0280
# Epoch 61/100
# 270/270 [==============================] - 0s 1ms/sample - loss: 0.0520 - val_loss: 0.0142
# Epoch 62/100
# 270/270 [==============================] - 0s 193us/sample - loss: 0.0567 - val_loss: 0.0211
# Epoch 63/100
# 270/270 [==============================] - 0s 189us/sample - loss: 0.0525 - val_loss: 0.0190
# Epoch 64/100
# 270/270 [==============================] - 0s 189us/sample - loss: 0.0524 - val_loss: 0.0257
# Epoch 65/100
# 270/270 [==============================] - 0s 185us/sample - loss: 0.0566 - val_loss: 0.0152
# Epoch 66/100
# 270/270 [==============================] - 0s 182us/sample - loss: 0.0647 - val_loss: 0.0245
# Epoch 67/100
# 270/270 [==============================] - 0s 189us/sample - loss: 0.0598 - val_loss: 0.0148
# Epoch 68/100
# 270/270 [==============================] - 0s 185us/sample - loss: 0.0578 - val_loss: 0.0163
# Epoch 69/100
# 270/270 [==============================] - 0s 178us/sample - loss: 0.0530 - val_loss: 0.0158
# Epoch 70/100
# 270/270 [==============================] - 0s 178us/sample - loss: 0.0557 - val_loss: 0.0269
# Epoch 71/100
# 270/270 [==============================] - 0s 170us/sample - loss: 0.0530 - val_loss: 0.0161
# Epoch 72/100
# 270/270 [==============================] - 0s 178us/sample - loss: 0.0536 - val_loss: 0.0206
# Epoch 73/100
# 270/270 [==============================] - 0s 170us/sample - loss: 0.0509 - val_loss: 0.0189
# Epoch 74/100
# 270/270 [==============================] - 0s 167us/sample - loss: 0.0441 - val_loss: 0.0178
# Epoch 75/100
# 270/270 [==============================] - 0s 178us/sample - loss: 0.0450 - val_loss: 0.0200
# Epoch 76/100
# 270/270 [==============================] - 0s 181us/sample - loss: 0.0421 - val_loss: 0.0202
# Epoch 77/100
# 270/270 [==============================] - 0s 178us/sample - loss: 0.0471 - val_loss: 0.0244
# Epoch 78/100
# 270/270 [==============================] - 0s 167us/sample - loss: 0.0492 - val_loss: 0.0180
# Epoch 79/100
# 270/270 [==============================] - 0s 170us/sample - loss: 0.0504 - val_loss: 0.0307
# Epoch 80/100
# 270/270 [==============================] - 0s 174us/sample - loss: 0.0529 - val_loss: 0.0156
# Epoch 81/100
# 270/270 [==============================] - 0s 174us/sample - loss: 0.0516 - val_loss: 0.0285
# Epoch 82/100
# 270/270 [==============================] - 0s 174us/sample - loss: 0.0421 - val_loss: 0.0178
# Epoch 83/100
# 270/270 [==============================] - 0s 189us/sample - loss: 0.0495 - val_loss: 0.0240
# Epoch 84/100
# 270/270 [==============================] - 0s 181us/sample - loss: 0.0445 - val_loss: 0.0203
# Epoch 85/100
# 270/270 [==============================] - 0s 178us/sample - loss: 0.0423 - val_loss: 0.0209
# Epoch 86/100
# 270/270 [==============================] - 0s 178us/sample - loss: 0.0409 - val_loss: 0.0199
# Epoch 87/100
# 270/270 [==============================] - 0s 181us/sample - loss: 0.0455 - val_loss: 0.0186
# Epoch 88/100
# 270/270 [==============================] - 0s 189us/sample - loss: 0.0469 - val_loss: 0.0296
# Epoch 89/100
# 270/270 [==============================] - 0s 761us/sample - loss: 0.0459 - val_loss: 0.0132
# Epoch 90/100
# 270/270 [==============================] - 0s 196us/sample - loss: 0.0443 - val_loss: 0.0227
# Epoch 91/100
# 270/270 [==============================] - 0s 207us/sample - loss: 0.0402 - val_loss: 0.0152
# Epoch 92/100
# 270/270 [==============================] - 0s 211us/sample - loss: 0.0427 - val_loss: 0.0181
# Epoch 93/100
# 270/270 [==============================] - 0s 200us/sample - loss: 0.0455 - val_loss: 0.0272
# Epoch 94/100
# 270/270 [==============================] - 0s 204us/sample - loss: 0.0460 - val_loss: 0.0169
# Epoch 95/100
# 270/270 [==============================] - 0s 200us/sample - loss: 0.0443 - val_loss: 0.0226
# Epoch 96/100
# 270/270 [==============================] - 0s 207us/sample - loss: 0.0436 - val_loss: 0.0150
# Epoch 97/100
# 270/270 [==============================] - 0s 207us/sample - loss: 0.0394 - val_loss: 0.0318
# Epoch 98/100
# 270/270 [==============================] - 0s 196us/sample - loss: 0.0469 - val_loss: 0.0218
# Epoch 99/100
# 270/270 [==============================] - 0s 189us/sample - loss: 0.0423 - val_loss: 0.0262
# Epoch 100/100
# 270/270 [==============================] - 0s 182us/sample - loss: 0.0415 - val_loss: 0.0152
# Model: "sequential_14"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# simple_rnn_24 (SimpleRNN)    multiple                  8560
# _________________________________________________________________
# dropout_28 (Dropout)         multiple                  0
# _________________________________________________________________
# simple_rnn_25 (SimpleRNN)    multiple                  18100
# _________________________________________________________________
# dropout_29 (Dropout)         multiple                  0
# _________________________________________________________________
# dense_20 (Dense)             multiple                  101
# =================================================================
# Total params: 26,761
# Trainable params: 26,761
# Non-trainable params: 0
# _________________________________________________________________
# ------------------------------

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.layers import Dropout, Dense, SimpleRNN
import matplotlib.pyplot as plt
import os
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error
import math
data = pd.read_csv(r"C:\Users\Administrator\Desktop\x_fe_poly.csv")
data = data.sort_values('id', ascending = False)


training_set = data.iloc[0:325 - 50, : ].values  # 前(325-50=275)天的数据作为训练集,表格从0开始计数
test_set = data.iloc[325 - 50: , : ].values  # 后50天的数据作为测试集

# 归一化
sc_x = MinMaxScaler(feature_range=(0, 1))  # 定义归一化：归一化到(0，1)之间
sc_y = MinMaxScaler(feature_range=(0, 1))  # 定义归一化：归一化到(0，1)之间
training_set_scaled_x = sc_x.fit_transform(training_set[:,2:])  # 求得训练集的最大值，最小值这些训练集固有的属性，并在训练集上进行归一化
training_set_scaled_y = sc_y.fit_transform(training_set[:,1:2])  # 求得训练集的最大值，最小值这些训练集固有的属性，并在训练集上进行归一化
test_set_x = sc_x.transform(test_set[:,2:])  # 利用训练集的属性对测试集进行归一化
test_set_y = sc_y.transform(test_set[:,1:2])  # 利用训练集的属性对测试集进行归一化

x_train = []
y_train = []

x_test = []
y_test = []

# 测试集：csv表格中前325-50=275个数据
# 利用for循环，遍历整个训练集，提取训练集中连续5天的26个降维新变量作为输入特征x_train，第6天的RON_LOSS作为标签，for循环共构建325-50-5=270组数据。

for i in range(5, len(training_set_scaled_x)):
    x_train.append(training_set_scaled_x[i - 5:i, :])
    y_train.append(training_set_scaled_y[i, :])
# 对训练集进行打乱
np.random.seed(7)
np.random.shuffle(x_train)
np.random.seed(7)
np.random.shuffle(y_train)
tf.random.set_seed(7)
# 将训练集由list格式变为array格式
x_train, y_train = np.array(x_train), np.array(y_train)

# 使x_train符合RNN输入要求：[送入样本数， 循环核时间展开步数， 每个时间步输入特征个数]。
# 此处整个数据集送入，送入样本数为x_train.shape[0]即270组数据；输入连续5个的26个降维新变量，预测出第6天的RON_LOSS，循环核时间展开步数为5; 每个时间步送入的特征是连续5天的26个降维新变量，有26个数据，故每个时间步输入特征个数为26
x_train = np.reshape(x_train, (x_train.shape[0], 5, 26))
# 测试集：csv表格中后50天数据
# 利用for循环，遍历整个测试集，提取测试集中连续5天的26个降维新变量作为输入特征x_train，第6天的数据作为RON_LOSS，for循环共构建50-5=45组数据。
for i in range(5, len(test_set_x)):
    x_test.append(test_set_x[i - 5 : i, :])
    y_test.append(test_set_y[i, :])
# 测试集变array并reshape为符合RNN输入要求：[送入样本数， 循环核时间展开步数， 每个时间步输入特征个数]
x_test, y_test = np.array(x_test), np.array(y_test)
x_test = np.reshape(x_test, (x_test.shape[0], 5, 26))

model_RNN = tf.keras.Sequential([
    SimpleRNN(80, return_sequences=True),
    Dropout(0.2),
    SimpleRNN(100),
    Dropout(0.2),
    Dense(1)
])

model_RNN.compile(optimizer=tf.keras.optimizers.Adam(0.001),
              loss='mean_squared_error')  # 损失函数用均方误差
# 该应用只观测loss数值，不观测准确率，所以删去metrics选项，一会在每个epoch迭代显示时只显示loss值
#C:\Users\Administrator\Desktop\
checkpoint_save_path = r"C:\Users\Administrator\Desktop\RNNcheckpoint\RNN_RON_LOSS.ckpt"

if os.path.exists(checkpoint_save_path + '.index'):
    print('-------------load the model_RNN-----------------')
    model_RNN.load_weights(checkpoint_save_path)

cp_callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_save_path,
                                                 save_weights_only=True,
                                                 save_best_only=True,
                                                 monitor='val_loss')

history = model_RNN.fit(x_train, y_train, batch_size=64, epochs=100, validation_data=(x_test, y_test), validation_freq=1,
                    callbacks=[cp_callback])

model_RNN.summary()


file = open('C:/Users/Administrator/Desktop/RNN_RON_LOSS_weights.txt', 'w' )  # 参数提取
for v in model_RNN.trainable_variables:
    file.write(str(v.name) + '\n')
    file.write(str(v.shape) + '\n')
    file.write(str(v.numpy()) + '\n')
file.close()

loss = history.history['loss']
val_loss = history.history['val_loss']
fig = plt.figure(figsize=[20,5] ,dpi = 250)
plt.plot(loss, label='RNN of Training Loss')
plt.plot(val_loss, label='RNN of Validation Loss')
plt.title(' RNN of Training and Validation Loss')
plt.legend()
#plt.show()
plt.savefig(r"C:\Users\Administrator\Desktop\RNN_Loss.jpg")

path_RNN = r"C:\Users\Administrator\Desktop\RNN_Loss.jpg"
if os.path.exists(path_RNN):
    print('------------------------------')
    fig = plt.figure(figsize=[20,5] ,dpi = 250)  
    #####看图######
    ################## predict ######################
    # 测试集输入模型进行预测
    predicted_RON_LOSS = model_RNN.predict(x_test)
    # 对预测数据还原---从（0，1）反归一化到原始范围
    predicted_RON_LOSS = sc_y.inverse_transform(predicted_RON_LOSS)
    # 对真实数据还原---从（0，1）反归一化到原始范围
    real_RON_LOSS = sc_y.inverse_transform(y_test)
    # 画出真实数据和预测数据的对比曲线
    plt.plot(real_RON_LOSS, color='red', label=' realed RON LOSS')
    plt.plot(predicted_RON_LOSS, color='blue', label=' RNN of Predicted RON LOSS')
    plt.title(' RNN of RON LOSS Prediction')
    plt.xlabel('Time')
    plt.ylabel('RON LOSS')
    plt.legend()
    #plt.show()
    plt.savefig(r"C:\Users\Administrator\Desktop\RNN_predict.jpg")


##########evaluate##############
# calculate MSE 均方误差 ---> E[(预测值-真实值)^2] (预测值减真实值求平方后求均值)
RNN_mse = mean_squared_error(predicted_RON_LOSS, real_RON_LOSS)
# calculate RMSE 均方根误差--->sqrt[MSE]    (对均方误差开方)
RNN_rmse = math.sqrt(mean_squared_error(predicted_RON_LOSS, real_RON_LOSS))
# calculate MAE 平均绝对误差----->E[|预测值-真实值|](预测值减真实值求绝对值后求均值）
RNN_mae = mean_absolute_error(predicted_RON_LOSS, real_RON_LOSS)
print('%s的均方误差: %.6f' % ("RNN",RNN_mse))
print('%s的均方根误差: %.6f' % ("RNN",RNN_rmse))
print('%s的平均绝对误差: %.6f' % ("RNN",RNN_mae))
# Out:
# Train on 270 samples, validate on 45 samples
# Epoch 1/100
# 270/270 [==============================] - 3s 9ms/sample - loss: 1.0966 - val_loss: 0.0743
# Epoch 2/100
# 270/270 [==============================] - 0s 222us/sample - loss: 0.7223 - val_loss: 0.1253
# Epoch 3/100
# 270/270 [==============================] - 0s 196us/sample - loss: 0.4265 - val_loss: 0.2684
# Epoch 4/100
# 270/270 [==============================] - 0s 185us/sample - loss: 0.4812 - val_loss: 0.1140
# Epoch 5/100
# 270/270 [==============================] - 0s 200us/sample - loss: 0.3383 - val_loss: 0.0757
# Epoch 6/100
# 270/270 [==============================] - 0s 808us/sample - loss: 0.2490 - val_loss: 0.0302
# Epoch 7/100
# 270/270 [==============================] - 0s 200us/sample - loss: 0.2129 - val_loss: 0.0369
# Epoch 8/100
# 270/270 [==============================] - 0s 759us/sample - loss: 0.2240 - val_loss: 0.0237
# Epoch 9/100
# 270/270 [==============================] - 0s 791us/sample - loss: 0.1949 - val_loss: 0.0234
# Epoch 10/100
# 270/270 [==============================] - 0s 222us/sample - loss: 0.2219 - val_loss: 0.0271
# Epoch 11/100
# 270/270 [==============================] - 0s 230us/sample - loss: 0.2001 - val_loss: 0.0236
# Epoch 12/100
# 270/270 [==============================] - 0s 200us/sample - loss: 0.1897 - val_loss: 0.0281
# Epoch 13/100
# 270/270 [==============================] - 0s 778us/sample - loss: 0.1677 - val_loss: 0.0220
# Epoch 14/100
# 270/270 [==============================] - 0s 239us/sample - loss: 0.1655 - val_loss: 0.0426
# Epoch 15/100
# 270/270 [==============================] - 0s 237us/sample - loss: 0.1545 - val_loss: 0.0230
# Epoch 16/100
# 270/270 [==============================] - 0s 237us/sample - loss: 0.1652 - val_loss: 0.0313
# Epoch 17/100
# 270/270 [==============================] - 0s 233us/sample - loss: 0.1735 - val_loss: 0.0301
# Epoch 18/100
# 270/270 [==============================] - 0s 230us/sample - loss: 0.1476 - val_loss: 0.0232
# Epoch 19/100
# 270/270 [==============================] - 0s 219us/sample - loss: 0.1237 - val_loss: 0.0484
# Epoch 20/100
# 270/270 [==============================] - 0s 222us/sample - loss: 0.1146 - val_loss: 0.0238
# Epoch 21/100
# 270/270 [==============================] - 0s 193us/sample - loss: 0.1457 - val_loss: 0.0372
# Epoch 22/100
# 270/270 [==============================] - 0s 196us/sample - loss: 0.1211 - val_loss: 0.0231
# Epoch 23/100
# 270/270 [==============================] - 0s 718us/sample - loss: 0.1140 - val_loss: 0.0194
# Epoch 24/100
# 270/270 [==============================] - 0s 200us/sample - loss: 0.1243 - val_loss: 0.0200
# Epoch 25/100
# 270/270 [==============================] - 0s 191us/sample - loss: 0.1047 - val_loss: 0.0197
# Epoch 26/100
# 270/270 [==============================] - 0s 181us/sample - loss: 0.0898 - val_loss: 0.0201
# Epoch 27/100
# 270/270 [==============================] - 0s 749us/sample - loss: 0.0933 - val_loss: 0.0177
# Epoch 28/100
# 270/270 [==============================] - 0s 185us/sample - loss: 0.0897 - val_loss: 0.0211
# Epoch 29/100
# 270/270 [==============================] - 0s 196us/sample - loss: 0.0914 - val_loss: 0.0264
# Epoch 30/100
# 270/270 [==============================] - 0s 193us/sample - loss: 0.0960 - val_loss: 0.0245
# Epoch 31/100
# 270/270 [==============================] - 0s 193us/sample - loss: 0.0901 - val_loss: 0.0204
# Epoch 32/100
# 270/270 [==============================] - 0s 193us/sample - loss: 0.0845 - val_loss: 0.0181
# Epoch 33/100
# 270/270 [==============================] - 0s 175us/sample - loss: 0.0832 - val_loss: 0.0269
# Epoch 34/100
# 270/270 [==============================] - 0s 842us/sample - loss: 0.0789 - val_loss: 0.0171
# Epoch 35/100
# 270/270 [==============================] - 0s 178us/sample - loss: 0.0965 - val_loss: 0.0380
# Epoch 36/100
# 270/270 [==============================] - 0s 719us/sample - loss: 0.0844 - val_loss: 0.0166
# Epoch 37/100
# 270/270 [==============================] - 0s 196us/sample - loss: 0.0655 - val_loss: 0.0176
# Epoch 38/100
# 270/270 [==============================] - 0s 189us/sample - loss: 0.0814 - val_loss: 0.0175
# Epoch 39/100
# 270/270 [==============================] - 0s 193us/sample - loss: 0.0846 - val_loss: 0.0245
# Epoch 40/100
# 270/270 [==============================] - 0s 196us/sample - loss: 0.0866 - val_loss: 0.0181
# Epoch 41/100
# 270/270 [==============================] - 0s 774us/sample - loss: 0.0698 - val_loss: 0.0158
# Epoch 42/100
# 270/270 [==============================] - 0s 1ms/sample - loss: 0.0730 - val_loss: 0.0152
# Epoch 43/100
# 270/270 [==============================] - 0s 248us/sample - loss: 0.0843 - val_loss: 0.0253
# Epoch 44/100
# 270/270 [==============================] - 0s 233us/sample - loss: 0.0756 - val_loss: 0.0175
# Epoch 45/100
# 270/270 [==============================] - 0s 215us/sample - loss: 0.0679 - val_loss: 0.0158
# Epoch 46/100
# 270/270 [==============================] - 0s 222us/sample - loss: 0.0774 - val_loss: 0.0309
# Epoch 47/100
# 270/270 [==============================] - 0s 222us/sample - loss: 0.0729 - val_loss: 0.0176
# Epoch 48/100
# 270/270 [==============================] - 0s 207us/sample - loss: 0.0668 - val_loss: 0.0195
# Epoch 49/100
# 270/270 [==============================] - 0s 204us/sample - loss: 0.0693 - val_loss: 0.0196
# Epoch 50/100
# 270/270 [==============================] - 0s 219us/sample - loss: 0.0653 - val_loss: 0.0196
# Epoch 51/100
# 270/270 [==============================] - 0s 200us/sample - loss: 0.0727 - val_loss: 0.0191
# Epoch 52/100
# 270/270 [==============================] - 0s 189us/sample - loss: 0.0761 - val_loss: 0.0177
# Epoch 53/100
# 270/270 [==============================] - 0s 189us/sample - loss: 0.0637 - val_loss: 0.0184
# Epoch 54/100
# 270/270 [==============================] - 0s 189us/sample - loss: 0.0648 - val_loss: 0.0165
# Epoch 55/100
# 270/270 [==============================] - 0s 178us/sample - loss: 0.0655 - val_loss: 0.0248
# Epoch 56/100
# 270/270 [==============================] - 0s 178us/sample - loss: 0.0561 - val_loss: 0.0166
# Epoch 57/100
# 270/270 [==============================] - 0s 185us/sample - loss: 0.0675 - val_loss: 0.0180
# Epoch 58/100
# 270/270 [==============================] - 0s 189us/sample - loss: 0.0670 - val_loss: 0.0222
# Epoch 59/100
# 270/270 [==============================] - 0s 182us/sample - loss: 0.0554 - val_loss: 0.0159
# Epoch 60/100
# 270/270 [==============================] - 0s 182us/sample - loss: 0.0591 - val_loss: 0.0280
# Epoch 61/100
# 270/270 [==============================] - 0s 1ms/sample - loss: 0.0520 - val_loss: 0.0142
# Epoch 62/100
# 270/270 [==============================] - 0s 185us/sample - loss: 0.0567 - val_loss: 0.0211
# Epoch 63/100
# 270/270 [==============================] - 0s 200us/sample - loss: 0.0525 - val_loss: 0.0190
# Epoch 64/100
# 270/270 [==============================] - 0s 189us/sample - loss: 0.0524 - val_loss: 0.0257
# Epoch 65/100
# 270/270 [==============================] - 0s 189us/sample - loss: 0.0566 - val_loss: 0.0152
# Epoch 66/100
# 270/270 [==============================] - 0s 193us/sample - loss: 0.0647 - val_loss: 0.0245
# Epoch 67/100
# 270/270 [==============================] - 0s 200us/sample - loss: 0.0598 - val_loss: 0.0148
# Epoch 68/100
# 270/270 [==============================] - 0s 200us/sample - loss: 0.0578 - val_loss: 0.0163
# Epoch 69/100
# 270/270 [==============================] - 0s 185us/sample - loss: 0.0530 - val_loss: 0.0158
# Epoch 70/100
# 270/270 [==============================] - 0s 189us/sample - loss: 0.0557 - val_loss: 0.0269
# Epoch 71/100
# 270/270 [==============================] - 0s 185us/sample - loss: 0.0530 - val_loss: 0.0161
# Epoch 72/100
# 270/270 [==============================] - 0s 189us/sample - loss: 0.0536 - val_loss: 0.0206
# Epoch 73/100
# 270/270 [==============================] - 0s 189us/sample - loss: 0.0509 - val_loss: 0.0189
# Epoch 74/100
# 270/270 [==============================] - 0s 193us/sample - loss: 0.0441 - val_loss: 0.0178
# Epoch 75/100
# 270/270 [==============================] - 0s 185us/sample - loss: 0.0450 - val_loss: 0.0200
# Epoch 76/100
# 270/270 [==============================] - 0s 181us/sample - loss: 0.0421 - val_loss: 0.0202
# Epoch 77/100
# 270/270 [==============================] - 0s 182us/sample - loss: 0.0471 - val_loss: 0.0244
# Epoch 78/100
# 270/270 [==============================] - 0s 185us/sample - loss: 0.0492 - val_loss: 0.0180
# Epoch 79/100
# 270/270 [==============================] - 0s 178us/sample - loss: 0.0504 - val_loss: 0.0307
# Epoch 80/100
# 270/270 [==============================] - 0s 193us/sample - loss: 0.0529 - val_loss: 0.0156
# Epoch 81/100
# 270/270 [==============================] - 0s 200us/sample - loss: 0.0516 - val_loss: 0.0285
# Epoch 82/100
# 270/270 [==============================] - 0s 200us/sample - loss: 0.0421 - val_loss: 0.0178
# Epoch 83/100
# 270/270 [==============================] - 0s 215us/sample - loss: 0.0495 - val_loss: 0.0240
# Epoch 84/100
# 270/270 [==============================] - 0s 196us/sample - loss: 0.0445 - val_loss: 0.0203
# Epoch 85/100
# 270/270 [==============================] - 0s 193us/sample - loss: 0.0423 - val_loss: 0.0209
# Epoch 86/100
# 270/270 [==============================] - 0s 185us/sample - loss: 0.0409 - val_loss: 0.0199
# Epoch 87/100
# 270/270 [==============================] - 0s 185us/sample - loss: 0.0455 - val_loss: 0.0186
# Epoch 88/100
# 270/270 [==============================] - 0s 181us/sample - loss: 0.0469 - val_loss: 0.0296
# Epoch 89/100
# 270/270 [==============================] - 0s 682us/sample - loss: 0.0459 - val_loss: 0.0132
# Epoch 90/100
# 270/270 [==============================] - 0s 219us/sample - loss: 0.0443 - val_loss: 0.0227
# Epoch 91/100
# 270/270 [==============================] - 0s 215us/sample - loss: 0.0402 - val_loss: 0.0152
# Epoch 92/100
# 270/270 [==============================] - 0s 219us/sample - loss: 0.0427 - val_loss: 0.0181
# Epoch 93/100
# 270/270 [==============================] - 0s 222us/sample - loss: 0.0455 - val_loss: 0.0272
# Epoch 94/100
# 270/270 [==============================] - 0s 219us/sample - loss: 0.0460 - val_loss: 0.0169
# Epoch 95/100
# 270/270 [==============================] - 0s 226us/sample - loss: 0.0443 - val_loss: 0.0226
# Epoch 96/100
# 270/270 [==============================] - 0s 219us/sample - loss: 0.0436 - val_loss: 0.0150
# Epoch 97/100
# 270/270 [==============================] - 0s 241us/sample - loss: 0.0394 - val_loss: 0.0318
# Epoch 98/100
# 270/270 [==============================] - 0s 219us/sample - loss: 0.0469 - val_loss: 0.0218
# Epoch 99/100
# 270/270 [==============================] - 0s 193us/sample - loss: 0.0423 - val_loss: 0.0262
# Epoch 100/100
# 270/270 [==============================] - 0s 193us/sample - loss: 0.0415 - val_loss: 0.0152
# Model: "sequential_15"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# simple_rnn_26 (SimpleRNN)    multiple                  8560
# _________________________________________________________________
# dropout_30 (Dropout)         multiple                  0
# _________________________________________________________________
# simple_rnn_27 (SimpleRNN)    multiple                  18100
# _________________________________________________________________
# dropout_31 (Dropout)         multiple                  0
# _________________________________________________________________
# dense_21 (Dense)             multiple                  101
# =================================================================
# Total params: 26,761
# Trainable params: 26,761
# Non-trainable params: 0
# _________________________________________________________________
# ------------------------------
# RNN的均方误差: 0.038790
# RNN的均方根误差: 0.196952
# RNN的平均绝对误差: 0.159756
